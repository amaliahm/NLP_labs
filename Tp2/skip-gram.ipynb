# %% [markdown]
# # feature extraction and embeddings

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import train_test_split
from gensim.models.keyedvectors import KeyedVectors
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from gensim.models import Word2Vec, FastText
from nltk.tokenize import word_tokenize
from sklearn.pipeline import Pipeline
from collections import defaultdict
from sklearn.svm import LinearSVC
import pandas as pd
import numpy as np
import random
import time

# %% [markdown]
# ## A. preparation de donnees

# %%
df = pd.read_csv('./spooky.csv')

# %%
df.head()
# Out:
#         id                                               text author
# 0  id26305  this proces however afforded me no means of as...    EAP
# 1  id17569  it never once occurred to me that the fumbling...    HPL
# 2  id11008  in his left hand was a gold snuff box from whi...    EAP
# 3  id27763  how lovely is spring as we looked from windsor...    MWS
# 4  id12958  finding nothing else not even gold the superin...    HPL

# %%
df.shape
# Out:
# (19579, 3)

# %%
df = df[: 100]

# %%
df.shape
# Out:
# (100, 3)

# %%
df['text'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## B. encodage de la variable a predire (facultatif)

# %%
label_encoder = LabelEncoder()
df['author_encoded'] = label_encoder.fit_transform(df['author'])

# %%
df.head()
# Out:
#         id                                               text author  \
# 0  id26305  this proces however afforded me no means of as...    EAP
# 1  id17569  it never once occurred to me that the fumbling...    HPL
# 2  id11008  in his left hand was a gold snuff box from whi...    EAP
# 3  id27763  how lovely is spring as we looked from windsor...    MWS
# 4  id12958  finding nothing else not even gold the superin...    HPL
#
#    author_encoded
# 0               0
# 1               1
# 2               0
# 3               2
# 4               1

# %% [markdown]
# ## C. construction des bases d’entraînement et de test

# %% [markdown]
#  tarining & test dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(df['text'], df['author_encoded'], test_size=0.3, random_state=0, stratify = df['author_encoded'])

# %% [markdown]
# obtenir une repartition similaire dans chaque classe du dataset

# %%
y_train.value_counts()
# Out:
# author_encoded
# 0    28
# 2    22
# 1    20
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# author_encoded
# 0    12
# 1     9
# 2     9
# Name: count, dtype: int64

# %%
y_train.value_counts()/y_test.value_counts()
# Out:
# author_encoded
# 0    2.333333
# 1    2.222222
# 2    2.444444
# Name: count, dtype: float64

# %% [markdown]
# ## D. methodes de vectorisation

# %% [markdown]
# vectoriser tarining & test dataset

# %% [markdown]
# ## G. vectorisation (embeddings de mots)

# %%
EPOCHS = 50
WINDOW_SIZE = 2
EMBEDDING_DIM = 5
LEARNING_RATE = 0.01

# %%
x_train.head()
# Out:
# 23    with how deep a spirit of wonder and perplexit...
# 28    our compases depth gauges and other delicate i...
# 85    ahead lay sparse grass and scrub blueberry bus...
# 48    dr johnson as i beheld him was a ful pursy man...
# 73    the next morning i delivered my letters of int...
# Name: text, dtype: object

# %%
words = [word for sentence in x_train for word in sentence.split()]
words
# Out:
# ['with',
#  'how',
#  'deep',
#  'a',
#  'spirit',
#  'of',
#  'wonder',
#  'and',
#  'perplexity',
#  'was',
#  'i',
#  'wont',
#  'to',
#  'regard',
#  'him',
#  'from',
#  'our',
#  'remote',
#  'pew',
#  'in',
#  'the',
#  'galery',
#  'as',
#  'with',
#  'step',
#  'solemn',
#  'and',
#  'slow',
#  'he',
#  'ascended',
#  'the',
#  'pulpit',
#  'this',
#  'reverend',
#  'man',
#  'with',
#  'countenance',
#  'so',
#  'demurely',
#  'benign',
#  'with',
#  'robes',
#  'so',
#  'glossy',
#  'and',
#  'so',
#  'clericaly',
#  'flowing',
#  'with',
#  'wig',
#  'so',
#  'minutely',
#  'powdered',
#  'so',
#  'rigid',
#  'and',
#  'so',
#  'vast',
#  'could',
#  'this',
#  'be',
#  'he',
#  'who',
#  'of',
#  'late',
#  'with',
#  'sour',
#  'visage',
#  'and',
#  'in',
#  'snufy',
#  'habiliments',
#  'administered',
#  'ferule',
#  'in',
#  'hand',
#  'the',
#  'draconian',
#  'laws',
#  'of',
#  'the',
#  'academy',
#  'our',
#  'compases',
#  'depth',
#  'gauges',
#  'and',
#  'other',
#  'delicate',
#  'instruments',
#  'were',
#  'ruined',
#  'so',
#  'that',
#  'henceforth',
#  'our',
#  'only',
#  'reckoning',
#  'would',
#  'be',
#  'gueswork',
#  'based',
#  'on',
#  'our',
#  'watches',
#  'the',
#  'calendar',
#  'and',
#  'our',
#  'apparent',
#  'drift',
#  'as',
#  'judged',
#  'by',
#  'any',
#  'objects',
#  'we',
#  'might',
#  'spy',
#  'through',
#  'the',
#  'portholes',
#  'or',
#  'from',
#  'the',
#  'conning',
#  'tower',
#  'ahead',
#  'lay',
#  'sparse',
#  'grass',
#  'and',
#  'scrub',
#  'blueberry',
#  'bushes',
#  'and',
#  'beyond',
#  'them',
#  'the',
#  'naked',
#  'rock',
#  'of',
#  'the',
#  'crag',
#  'and',
#  'the',
#  'thin',
#  'peak',
#  'of',
#  'the',
#  'dreaded',
#  'grey',
#  'cotage',
#  'dr',
#  'johnson',
#  'as',
#  'i',
#  'beheld',
#  'him',
#  'was',
#  'a',
#  'ful',
#  'pursy',
#  'man',
#  'very',
#  'ill',
#  'drest',
#  'and',
#  'of',
#  'slovenly',
#  'aspect',
#  'the',
#  'next',
#  'morning',
#  'i',
#  'delivered',
#  'my',
#  'letters',
#  'of',
#  'introduction',
#  'and',
#  'paid',
#  'a',
#  'visit',
#  'to',
#  'some',
#  'of',
#  'the',
#  'principal',
#  'profesors',
#  'i',
#  'seemed',
#  'to',
#  'be',
#  'upon',
#  'the',
#  'verge',
#  'of',
#  'comprehension',
#  'without',
#  'power',
#  'to',
#  'comprehend',
#  'men',
#  'at',
#  'times',
#  'find',
#  'themselves',
#  'upon',
#  'the',
#  'brink',
#  'of',
#  'remembrance',
#  'without',
#  'being',
#  'able',
#  'in',
#  'the',
#  'end',
#  'to',
#  'remember',
#  'i',
#  'pointed',
#  'to',
#  'the',
#  'spot',
#  'where',
#  'he',
#  'had',
#  'disapeared',
#  'and',
#  'we',
#  'followed',
#  'the',
#  'track',
#  'with',
#  'boats',
#  'nets',
#  'were',
#  'cast',
#  'but',
#  'in',
#  'vain',
#  'finding',
#  'nothing',
#  'else',
#  'not',
#  'even',
#  'gold',
#  'the',
#  'superintendent',
#  'abandoned',
#  'his',
#  'atempts',
#  'but',
#  'a',
#  'perplexed',
#  'look',
#  'occasionally',
#  'steals',
#  'over',
#  'his',
#  'countenance',
#  'as',
#  'he',
#  'sits',
#  'thinking',
#  'at',
#  'his',
#  'desk',
#  'on',
#  'every',
#  'hand',
#  'was',
#  'a',
#  'wilderness',
#  'of',
#  'balconies',
#  'of',
#  'verandas',
#  'of',
#  'minarets',
#  'of',
#  'shrines',
#  'and',
#  'fantastically',
#  'carved',
#  'oriels',
#  'and',
#  'quivering',
#  'awhile',
#  'among',
#  'the',
#  'draperies',
#  'of',
#  'the',
#  'rom',
#  'it',
#  'at',
#  'length',
#  'rested',
#  'in',
#  'full',
#  'view',
#  'upon',
#  'the',
#  'surface',
#  'of',
#  'the',
#  'door',
#  'of',
#  'bras',
#  'that',
#  'is',
#  'absolutely',
#  'nedles',
#  'replied',
#  'g',
#  'to',
#  'these',
#  'speeches',
#  'they',
#  'gave',
#  'of',
#  'course',
#  'their',
#  'own',
#  'interpretation',
#  'fancying',
#  'no',
#  'doubt',
#  'that',
#  'at',
#  'all',
#  'events',
#  'i',
#  'should',
#  'come',
#  'into',
#  'possession',
#  'of',
#  'vast',
#  'quantities',
#  'of',
#  'ready',
#  'money',
#  'and',
#  'provided',
#  'i',
#  'paid',
#  'them',
#  'all',
#  'i',
#  'owed',
#  'and',
#  'a',
#  'trifle',
#  'more',
#  'in',
#  'consideration',
#  'of',
#  'their',
#  'services',
#  'i',
#  'dare',
#  'say',
#  'they',
#  'cared',
#  'very',
#  'little',
#  'what',
#  'became',
#  'of',
#  'either',
#  'my',
#  'soul',
#  'or',
#  'my',
#  'carcas',
#  'the',
#  'lips',
#  'were',
#  'of',
#  'the',
#  'usual',
#  'marble',
#  'palor',
#  'maternal',
#  'affection',
#  'had',
#  'not',
#  'rendered',
#  'idris',
#  'selfish',
#  'at',
#  'the',
#  'beginning',
#  'of',
#  'our',
#  'calamity',
#  'she',
#  'had',
#  'with',
#  'thoughtless',
#  'enthusiasm',
#  'devoted',
#  'herself',
#  'to',
#  'the',
#  'care',
#  'of',
#  'the',
#  'sick',
#  'and',
#  'helples',
#  'how',
#  'this',
#  'celebrated',
#  'magazine',
#  'can',
#  'sustain',
#  'its',
#  'evidently',
#  'tremendous',
#  'expenses',
#  'is',
#  'more',
#  'than',
#  'we',
#  'can',
#  'understand',
#  'the',
#  'visits',
#  'of',
#  'merival',
#  'to',
#  'windsor',
#  'before',
#  'frequent',
#  'had',
#  'suddenly',
#  'ceased',
#  'in',
#  'a',
#  'week',
#  'or',
#  'two',
#  'it',
#  'had',
#  'visibly',
#  'faded',
#  'and',
#  'in',
#  'the',
#  'course',
#  'of',
#  'a',
#  'few',
#  'months',
#  'it',
#  'was',
#  'hardly',
#  'discernible',
#  'with',
#  'the',
#  'naked',
#  'eye',
#  'his',
#  'facial',
#  'aspect',
#  'to',
#  'was',
#  'remarkable',
#  'for',
#  'its',
#  'maturity',
#  'for',
#  'though',
#  'he',
#  'shared',
#  'his',
#  'mothers',
#  'and',
#  'grandfathers',
#  'chinlesnes',
#  'his',
#  'firm',
#  'and',
#  'precociously',
#  'shaped',
#  'nose',
#  'united',
#  'with',
#  'the',
#  'expression',
#  'of',
#  'his',
#  'large',
#  'dark',
#  'almost',
#  'latin',
#  'eyes',
#  'to',
#  'give',
#  'him',
#  'an',
#  'air',
#  'of',
#  'quasi',
#  'adulthood',
#  'and',
#  'well',
#  'nigh',
#  'preternatural',
#  'inteligence',
#  'to',
#  'be',
#  'near',
#  'him',
#  'to',
#  'be',
#  'loved',
#  'by',
#  'him',
#  'to',
#  'feel',
#  'him',
#  'again',
#  'her',
#  'own',
#  'was',
#  'the',
#  'limit',
#  'of',
#  'her',
#  'desires',
#  'her',
#  'native',
#  'sprightliness',
#  'needed',
#  'no',
#  'undue',
#  'excitement',
#  'and',
#  'her',
#  'placid',
#  'heart',
#  'reposed',
#  'contented',
#  'on',
#  'my',
#  'love',
#  'the',
#  'well',
#  'being',
#  'of',
#  'her',
#  'children',
#  'and',
#  'the',
#  'beauty',
#  'of',
#  'surrounding',
#  'nature',
#  'it',
#  'was',
#  'not',
#  'that',
#  'the',
#  'sounds',
#  'were',
#  'hideous',
#  'for',
#  'they',
#  'were',
#  'not',
#  'but',
#  'that',
#  'they',
#  'held',
#  'vibrations',
#  'suggesting',
#  'nothing',
#  'on',
#  'this',
#  'globe',
#  'of',
#  'earth',
#  'and',
#  'that',
#  'at',
#  'certain',
#  'intervals',
#  'they',
#  'assumed',
#  'a',
#  'symphonic',
#  'quality',
#  'which',
#  'i',
#  'could',
#  'hardly',
#  'conceive',
#  'as',
#  'produced',
#  'by',
#  'one',
#  'player',
#  'and',
#  'the',
#  'childrens',
#  'children',
#  'and',
#  'the',
#  'newcomers',
#  'children',
#  'grew',
#  'up',
#  'they',
#  'were',
#  'marched',
#  'to',
#  'various',
#  'parts',
#  'of',
#  'the',
#  'southern',
#  'counties',
#  'quartered',
#  'in',
#  'deserted',
#  'vilages',
#  'a',
#  'part',
#  'were',
#  'sent',
#  'back',
#  'to',
#  'their',
#  'own',
#  'island',
#  'while',
#  'the',
#  'season',
#  'of',
#  'winter',
#  'so',
#  'far',
#  'revived',
#  'our',
#  'energy',
#  'that',
#  'the',
#  'passes',
#  'of',
#  'the',
#  'country',
#  'were',
#  'defended',
#  'and',
#  'any',
#  'increase',
#  'of',
#  'numbers',
#  'prohibited',
#  'it',
#  'is',
#  'not',
#  'to',
#  'be',
#  'suposed',
#  'however',
#  'that',
#  'the',
#  'great',
#  'underduk',
#  'suffered',
#  'this',
#  'impertinence',
#  'on',
#  'the',
#  'part',
#  'of',
#  'the',
#  'little',
#  'old',
#  'man',
#  'to',
#  'pass',
#  'off',
#  'with',
#  'impunity',
#  'pausing',
#  'i',
#  'succeeded',
#  'with',
#  'difficulty',
#  'in',
#  'raising',
#  'it',
#  'whereupon',
#  'there',
#  'was',
#  'revealed',
#  'a',
#  'black',
#  'aperture',
#  'exhaling',
#  'noxious',
#  'fumes',
#  'which',
#  'caused',
#  'my',
#  'torch',
#  'to',
#  'sputer',
#  'and',
#  'disclosing',
#  'in',
#  'the',
#  'unsteady',
#  'glare',
#  'the',
#  'top',
#  'of',
#  'a',
#  'flight',
#  'of',
#  'stone',
#  'steps',
#  'it',
#  'was',
#  'all',
#  'mud',
#  'an',
#  'water',
#  'an',
#  'the',
#  'sky',
#  'was',
#  'dark',
#  'an',
#  'the',
#  'rain',
#  'was',
#  'wipin',
#  'aout',
#  'all',
#  'tracks',
#  'abaout',
#  'as',
#  'fast',
#  'as',
#  'could',
#  'be',
#  'but',
#  'beginin',
#  'at',
#  'the',
#  'glen',
#  'maouth',
#  'whar',
#  'the',
#  'trees',
#  'had',
#  'moved',
#  'they',
#  'was',
#  'still',
#  'some',
#  'o',
#  'them',
#  'awful',
#  'prints',
#  'big',
#  'as',
#  'barls',
#  'like',
#  'he',
#  'seen',
#  'monday',
#  'we',
#  'could',
#  'make',
#  'out',
#  'little',
#  'by',
#  'the',
#  'dim',
#  'light',
#  'but',
#  'they',
#  'seemed',
#  'to',
#  'contain',
#  'prophecies',
#  'detailed',
#  'relations',
#  'of',
#  'events',
#  'but',
#  'lately',
#  'pased',
#  'names',
#  'now',
#  'well',
#  'known',
#  'but',
#  'of',
#  'modern',
#  'date',
#  'and',
#  'often',
#  'exclamations',
#  'of',
#  'exultation',
#  'or',
#  'woe',
#  'of',
#  'victory',
#  'or',
#  'defeat',
#  'were',
#  'traced',
#  'on',
#  'their',
#  'thin',
#  'scant',
#  'pages',
#  'i',
#  'even',
#  'went',
#  'so',
#  'far',
#  'as',
#  'to',
#  'speak',
#  'of',
#  'a',
#  'slightly',
#  'hectic',
#  'cough',
#  'with',
#  'which',
#  'at',
#  'one',
#  'time',
#  'i',
#  'had',
#  'been',
#  'troubled',
#  'of',
#  'a',
#  'chronic',
#  'rheumatism',
#  'of',
#  'a',
#  'twinge',
#  'of',
#  'hereditary',
#  'gout',
#  'and',
#  'in',
#  'conclusion',
#  'of',
#  'the',
#  'disagreeable',
#  'and',
#  'inconvenient',
#  'but',
#  'hitherto',
#  'carefully',
#  'concealed',
#  'weakness',
#  'of',
#  'my',
#  'eyes',
#  'i',
#  'panted',
#  'i',
#  'gasped',
#  'for',
#  'breath',
#  'there',
#  'could',
#  'be',
#  'no',
#  'doubt',
#  'of',
#  'the',
#  'design',
#  'of',
#  'my',
#  'tormentors',
#  'oh',
#  'most',
#  'unrelenting',
#  'oh',
#  'most',
#  'demoniac',
#  'of',
#  'men',
#  'i',
#  'shrank',
#  'from',
#  'the',
#  'glowing',
#  'metal',
#  'to',
#  'the',
#  'centre',
#  'of',
#  'the',
#  'cel',
#  'it',
#  'was',
#  'getting',
#  'dark',
#  'and',
#  'the',
#  'ancient',
#  'roofs',
#  'and',
#  'chimney',
#  'pots',
#  'outside',
#  'looked',
#  'very',
#  'queer',
#  'through',
#  'the',
#  'buls',
#  'eye',
#  'window',
#  'panes',
#  'each',
#  'people',
#  'looked',
#  'on',
#  'the',
#  'coming',
#  'struggle',
#  'as',
#  'that',
#  'which',
#  'would',
#  'be',
#  'to',
#  'a',
#  'great',
#  'degree',
#  'decisive',
#  'as',
#  'in',
#  'case',
#  'of',
#  'victory',
#  'the',
#  'next',
#  'step',
#  'would',
#  'be',
#  'the',
#  'siege',
#  'of',
#  'constantinople',
#  'by',
#  'the',
#  'greks',
#  'he',
#  'came',
#  'like',
#  'a',
#  'protecting',
#  'spirit',
#  'to',
#  'the',
#  'poor',
#  'girl',
#  'who',
#  'committed',
#  'herself',
#  'to',
#  'his',
#  'care',
#  'and',
#  'after',
#  'the',
#  'interment',
#  'of',
#  'his',
#  'friend',
#  'he',
#  'conducted',
#  'her',
#  'to',
#  'geneva',
#  'and',
#  'placed',
#  'her',
#  ...]

# %%
vocab = list(set(words))
vocab
# Out:
# ['slovenly',
#  'atempts',
#  'calamity',
#  'gold',
#  'little',
#  'afore',
#  'quality',
#  'shield',
#  'car',
#  'committed',
#  'tribe',
#  'present',
#  'keep',
#  'endless',
#  'draperies',
#  'spy',
#  'impunity',
#  'would',
#  'flowing',
#  'rem',
#  'fairly',
#  'chance',
#  'glen',
#  'out',
#  'met',
#  'let',
#  'time',
#  'noble',
#  'amidst',
#  'provided',
#  'genial',
#  'have',
#  'sputer',
#  'we',
#  'warriors',
#  'breath',
#  'mouth',
#  'knew',
#  'before',
#  'courage',
#  'better',
#  'conning',
#  'moved',
#  'certainly',
#  'verge',
#  'near',
#  'finding',
#  'bursts',
#  'make',
#  'nose',
#  'obedience',
#  'kep',
#  'changes',
#  'paleness',
#  'dyin',
#  'he',
#  'wiliam',
#  'states',
#  'murdered',
#  'kind',
#  'without',
#  'extravagant',
#  'blueberry',
#  'boats',
#  'parts',
#  'box',
#  'often',
#  'magazine',
#  'beauty',
#  'each',
#  'ultimate',
#  'birth',
#  'not',
#  'helples',
#  'facial',
#  'water',
#  'galopin',
#  'state',
#  'wig',
#  'gentle',
#  'daown',
#  'gently',
#  'friendship',
#  'moments',
#  'wars',
#  'exist',
#  'cold',
#  'california',
#  'get',
#  'must',
#  'neither',
#  'evening',
#  'youth',
#  'a',
#  'shade',
#  'wildest',
#  'pigeons',
#  'various',
#  'bushes',
#  'absolutely',
#  'gauges',
#  'conducted',
#  'energy',
#  'breakers',
#  'prints',
#  'concealed',
#  'drest',
#  'destruction',
#  'cast',
#  'sounds',
#  'plane',
#  'mnar',
#  'plague',
#  'marched',
#  'ever',
#  'ago',
#  'instruments',
#  'monday',
#  'condition',
#  'wide',
#  'known',
#  'how',
#  'clammy',
#  'place',
#  'lie',
#  'pursue',
#  'dizzily',
#  'muscular',
#  'geneva',
#  'rudimentary',
#  'peculiar',
#  'fantastic',
#  'window',
#  'brutality',
#  'interior',
#  'exceeding',
#  'piteously',
#  'presumably',
#  'point',
#  'desk',
#  'modern',
#  'apparently',
#  'under',
#  'underduk',
#  'cared',
#  'table',
#  'vilages',
#  'distressed',
#  'profesors',
#  'delivered',
#  'turned',
#  'henceforth',
#  'ib',
#  'winter',
#  'exercised',
#  'peak',
#  'far',
#  'oriels',
#  'academy',
#  'rheumatism',
#  'four',
#  'believed',
#  'events',
#  'about',
#  'player',
#  'draconian',
#  'unable',
#  'cat',
#  'greks',
#  'board',
#  'children',
#  'degree',
#  'perhaps',
#  'love',
#  'elipse',
#  'course',
#  'word',
#  'gout',
#  'gained',
#  'names',
#  'length',
#  'sent',
#  'being',
#  'maternal',
#  'flight',
#  'galery',
#  'journey',
#  'deep',
#  'abandoned',
#  'fast',
#  'either',
#  'hardly',
#  'foot',
#  'atomies',
#  'orion',
#  'friend',
#  'your',
#  'precociously',
#  'visit',
#  'end',
#  'spent',
#  'decisive',
#  'hereditary',
#  'changing',
#  'nebula',
#  'up',
#  'carefully',
#  'staggered',
#  'united',
#  'tower',
#  'protecting',
#  'alarm',
#  'portrait',
#  'step',
#  'von',
#  'selfish',
#  'heard',
#  'fever',
#  'pots',
#  'attractions',
#  'details',
#  'beheld',
#  'gods',
#  'astronomer',
#  'taken',
#  'slightly',
#  'else',
#  'diminution',
#  'branch',
#  'vague',
#  'companionles',
#  'back',
#  'ear',
#  'calendar',
#  'world',
#  'sick',
#  'ful',
#  'on',
#  'more',
#  'verandas',
#  'wipin',
#  'people',
#  'ailments',
#  'whereupon',
#  'its',
#  'difficulty',
#  'spreading',
#  'view',
#  'best',
#  'come',
#  'courtyard',
#  'consideration',
#  'carved',
#  'signs',
#  'wings',
#  'bed',
#  'protection',
#  'crag',
#  'seemed',
#  'counties',
#  'symphonic',
#  'flux',
#  'hoped',
#  'pages',
#  'confess',
#  'they',
#  'continued',
#  'hitherto',
#  'contented',
#  'powdered',
#  'late',
#  'prohibited',
#  'sign',
#  'grey',
#  'girl',
#  'clouds',
#  'legrand',
#  'court',
#  'persons',
#  'quantities',
#  'fal',
#  'most',
#  'd',
#  'you',
#  'from',
#  'dr',
#  'surrounding',
#  'tormentors',
#  'defended',
#  'enthusiasm',
#  'siege',
#  'decreased',
#  'lately',
#  'inevitably',
#  'silent',
#  'remember',
#  'owed',
#  'administered',
#  'based',
#  'demurely',
#  'succeeded',
#  'shouldst',
#  'coming',
#  'sour',
#  'three',
#  'teach',
#  'dampness',
#  'them',
#  'change',
#  'notice',
#  'listened',
#  'characteristicaly',
#  'there',
#  'defeat',
#  'conquered',
#  'replaced',
#  'ply',
#  'unite',
#  'rather',
#  'feline',
#  'wonder',
#  'followed',
#  'cotage',
#  'fancying',
#  'expression',
#  'like',
#  'relation',
#  'affairs',
#  'information',
#  'structure',
#  'slow',
#  'tombs',
#  'thinking',
#  'eyes',
#  'snake',
#  'necesary',
#  'that',
#  'his',
#  'big',
#  'at',
#  'referring',
#  'still',
#  'however',
#  'ancient',
#  'sold',
#  'reckoning',
#  'chronic',
#  'snuff',
#  'involved',
#  'down',
#  'marble',
#  'few',
#  'really',
#  'took',
#  'waves',
#  'wil',
#  'star',
#  'threw',
#  'dim',
#  'in',
#  'sprightliness',
#  'wilderness',
#  'care',
#  'busy',
#  'bras',
#  'whirlpool',
#  'progress',
#  'greatest',
#  'thing',
#  'perplexity',
#  'man',
#  'trifle',
#  'buls',
#  'fatality',
#  'case',
#  'pulpit',
#  'got',
#  'inconvenient',
#  'all',
#  'great',
#  'longer',
#  'might',
#  'well',
#  'paid',
#  'commence',
#  'shared',
#  'over',
#  'weakness',
#  'capered',
#  'secure',
#  'appeared',
#  'system',
#  'sharp',
#  'demoniac',
#  'islanders',
#  'mothers',
#  'panes',
#  'overflowed',
#  'beginning',
#  'roofs',
#  'year',
#  'inteligence',
#  'numbers',
#  'appointed',
#  'upon',
#  'rom',
#  'into',
#  'overcome',
#  'suddenly',
#  'mariner',
#  'cloaks',
#  'said',
#  'looked',
#  'everybody',
#  'arnheim',
#  'ide',
#  'inquiries',
#  'resolved',
#  'newcomers',
#  'general',
#  'metal',
#  'dared',
#  'suposed',
#  'grass',
#  'be',
#  'excitement',
#  'incessantly',
#  'safety',
#  'sea',
#  'discovery',
#  'morning',
#  'profesion',
#  'influence',
#  'one',
#  'paradise',
#  'contain',
#  'find',
#  'minarets',
#  'those',
#  'singularly',
#  'the',
#  'naked',
#  'since',
#  'became',
#  'vibrations',
#  'pew',
#  'atrophied',
#  'ascended',
#  'assumed',
#  'clericaly',
#  'noted',
#  'stood',
#  'nearly',
#  'did',
#  'rested',
#  'remarkable',
#  'globe',
#  'produced',
#  'say',
#  'constantinople',
#  'whole',
#  'lead',
#  'afterward',
#  'interest',
#  'reflection',
#  'away',
#  'ferule',
#  'wont',
#  'first',
#  'aperture',
#  'fumes',
#  'escape',
#  'ocean',
#  'awhile',
#  'now',
#  'services',
#  'acting',
#  'some',
#  'exhaling',
#  'matter',
#  'troubled',
#  'cutting',
#  'outside',
#  'western',
#  'air',
#  'devoted',
#  'start',
#  'mountainous',
#  'us',
#  'suggestion',
#  'light',
#  'reposed',
#  'feel',
#  'who',
#  'take',
#  'results',
#  'nebular',
#  'found',
#  'introduction',
#  'placed',
#  'will',
#  'tissue',
#  'long',
#  'seen',
#  'shehan',
#  'governments',
#  'discernible',
#  'centre',
#  'largest',
#  'thoughts',
#  'suffered',
#  'palor',
#  'posesion',
#  'left',
#  'whar',
#  'barricaded',
#  'concerning',
#  'pure',
#  'cosmogony',
#  'wilburs',
#  'sufficiently',
#  'my',
#  'declivity',
#  'themselves',
#  'stone',
#  'it',
#  'portholes',
#  'hideous',
#  'struggle',
#  'pestilence',
#  'side',
#  'other',
#  'sits',
#  'road',
#  'hours',
#  'top',
#  'luminosity',
#  'limit',
#  'maouth',
#  'faces',
#  'theories',
#  'spot',
#  'benign',
#  'war',
#  'or',
#  'old',
#  'tracks',
#  'tremendous',
#  'any',
#  'nor',
#  'value',
#  'which',
#  'give',
#  'sustain',
#  'another',
#  'below',
#  'made',
#  'ardent',
#  'g',
#  'survive',
#  'presently',
#  'greatly',
#  'remote',
#  'especially',
#  'destructive',
#  'these',
#  'through',
#  'upward',
#  'tell',
#  'canot',
#  'windows',
#  'i',
#  'remembrance',
#  'usually',
#  'chimney',
#  'poor',
#  'sky',
#  'forrad',
#  'cut',
#  'politics',
#  'me',
#  'getting',
#  'johnson',
#  'phenomenal',
#  'minded',
#  'only',
#  'came',
#  'document',
#  'atmosphere',
#  'lieutenant',
#  'track',
#  'victory',
#  'soul',
#  'hil',
#  'inhabitants',
#  'leadership',
#  'when',
#  'had',
#  'somethin',
#  'nothing',
#  'fantastically',
#  'across',
#  'times',
#  'raising',
#  'unrelenting',
#  'principal',
#  'pointed',
#  'canoe',
#  'hesitate',
#  'unknown',
#  'furniture',
#  'earth',
#  'affection',
#  'rest',
#  'substances',
#  'intervals',
#  'pausing',
#  'kempelens',
#  'studies',
#  'greek',
#  'generate',
#  'thin',
#  'remained',
#  'desirous',
#  'hand',
#  'queer',
#  'escaped',
#  'disclosing',
#  'contraction',
#  'hectic',
#  'has',
#  'vain',
#  'nigh',
#  'gasped',
#  'struggled',
#  'self',
#  'rich',
#  'what',
#  'analogy',
#  'visits',
#  'quivering',
#  'island',
#  'increase',
#  'just',
#  'connection',
#  'phrase',
#  'sunny',
#  'able',
#  'combat',
#  'arter',
#  'ruined',
#  'firm',
#  'size',
#  'solemn',
#  'speculation',
#  'intrigues',
#  'objects',
#  'latin',
#  'brow',
#  'vestiges',
#  'spread',
#  'nature',
#  'occasionally',
#  'childrens',
#  'snufy',
#  'exultation',
#  'meantime',
#  'within',
#  'spirit',
#  'poison',
#  'endure',
#  'oh',
#  'steps',
#  'al',
#  'almost',
#  'shone',
#  'after',
#  'avoid',
#  'means',
#  'disapeared',
#  'hope',
#  'look',
#  'nedles',
#  'evidently',
#  'imagination',
#  'faded',
#  'talked',
#  'eastward',
#  'want',
#  'albertus',
#  'respect',
#  'where',
#  'native',
#  'ill',
#  'impertinence',
#  'o',
#  'her',
#  'never',
#  'accustomed',
#  'gave',
#  'here',
#  'thus',
#  'accession',
#  'casting',
#  'grandfathers',
#  'southern',
#  'conclusion',
#  'sparse',
#  'proportions',
#  'glare',
#  'merival',
#  'compases',
#  'shrank',
#  'wel',
#  'even',
#  'wonderful',
#  'woe',
#  'drift',
#  'every',
#  'climate',
#  'understand',
#  'immediate',
#  'speeches',
#  'trees',
#  'torch',
#  'an',
#  'full',
#  'ship',
#  'minutely',
#  'went',
#  'unrecognised',
#  'looking',
#  'scant',
#  'do',
#  'intense',
#  'deserted',
#  'agripa',
#  'beginin',
#  'satisfaction',
#  'collecting',
#  'superintendent',
#  'rendered',
#  'panted',
#  'organs',
#  'country',
#  'fro',
#  'loved',
#  'suggesting',
#  'mewed',
#  'infants',
#  'building',
#  'doubt',
#  'underwent',
#  'balconies',
#  'pased',
#  'men',
#  'interment',
#  'set',
#  'abruptly',
#  'prodigies',
#  'disagreeable',
#  'fire',
#  'mud',
#  'years',
#  'very',
#  'by',
#  'shrines',
#  'letters',
#  'quasi',
#  'raymond',
#  'celebrated',
#  'visibly',
#  'traced',
#  'age',
#  'simply',
#  'feminine',
#  'secret',
#  'season',
#  'week',
#  'two',
#  'prophecies',
#  'reverend',
#  'behind',
#  'thy',
#  'than',
#  'scrub',
#  'stereotomy',
#  'rain',
#  'mobile',
#  'maturity',
#  'possessed',
#  'fell',
#  'but',
#  'thou',
#  'part',
#  'windsor',
#  'character',
#  'him',
#  'excep',
#  'among',
#  'refined',
#  'bit',
#  'again',
#  'refuge',
#  'discussed',
#  'inopportuneness',
#  'growth',
#  'months',
#  'ahead',
#  'land',
#  'attained',
#  'judged',
#  'observed',
#  'doors',
#  'room',
#  'guesses',
#  'wondrous',
#  'confirmation',
#  'lips',
#  'many',
#  'depth',
#  'increased',
#  'manner',
#  'foaming',
#  'epicurus',
#  'constantly',
#  'thoughtless',
#  'aout',
#  'countenance',
#  'dilation',
#  'bugs',
#  'machine',
#  'analysis',
#  'serene',
#  'pass',
#  'glowing',
#  'quartered',
#  'act',
#  'sunk',
#  'date',
#  'somewhat',
#  'unsteady',
#  'undue',
#  'preternatural',
#  'horizon',
#  'speak',
#  'could',
#  'equal',
#  'so',
#  'violence',
#  'delicate',
#  'expenses',
#  'paracelsus',
#  'nets',
#  'readily',
#  'power',
#  'regard',
#  'cough',
#  'myself',
#  'eliciting',
#  'been',
#  'door',
#  'should',
#  'non',
#  'struck',
#  'grew',
#  'languages',
#  'cud',
#  'passed',
#  'symbol',
#  'rock',
#  'barls',
#  'abaout',
#  'expected',
#  'unpleasant',
#  'while',
#  'laws',
#  'availability',
#  'engulfed',
#  'placid',
#  'heart',
#  'pursy',
#  'render',
#  'pupils',
#  'interpretation',
#  'swiftly',
#  'bite',
#  'dare',
#  'revealed',
#  'adulthood',
#  'twinge',
#  'design',
#  'importance',
#  'aspect',
#  'conceive',
#  'disinclined',
#  'desires',
#  'chinlesnes',
#  'society',
#  'needed',
#  'till',
#  'equally',
#  'lords',
#  'herself',
#  'frequent',
#  'sarnath',
#  'no',
#  'next',
#  'peculiarly',
#  'money',
#  'own',
#  'itself',
#  'ices',
#  'think',
#  'beings',
#  'to',
#  'such',
#  'kindliness',
#  'advancement',
#  'madly',
#  'guardian',
#  'sense',
#  'was',
#  'horrible',
#  'fet',
#  'revived',
#  'with',
#  'extreme',
#  'enabled',
#  'is',
#  'sacrifices',
#  'watches',
#  'shaped',
#  'comprehension',
#  'sordidness',
#  'certain',
#  'off',
#  'were',
#  'terific',
#  'and',
#  'steals',
#  'held',
#  'wrapping',
#  'dark',
#  'murmur',
#  'yet',
#  'cornelius',
#  'fanciful',
#  'developments',
#  'can',
#  'exclamations',
#  'abroad',
#  'habiliments',
#  'heavy',
#  'ample',
#  'magnus',
#  'this',
#  'blankets',
#  'around',
#  'beyond',
#  'sun',
#  'ready',
#  'cel',
#  'sole',
#  'disadvantages',
#  'brought',
#  'eye',
#  'possible',
#  'our',
#  'brings',
#  'for',
#  'rigid',
#  'caused',
#  'follow',
#  'conquest',
#  'apparent',
#  'mentioned',
#  'glory',
#  'usual',
#  'idea',
#  'as',
#  'overthrow',
#  'if',
#  'of',
#  'she',
#  'afections',
#  'young',
#  'yourself',
#  'robes',
#  'carcas',
#  'groundwork',
#  'descended',
#  'enterprise',
#  'crew',
#  'solitude',
#  'brink',
#  'scheme',
#  'code',
#  'surface',
#  'distaste',
#  ...]

# %%
word2idx = {word: i for i, word in enumerate(vocab)}
word2idx
# Out:
# {'slovenly': 0,
#  'atempts': 1,
#  'calamity': 2,
#  'gold': 3,
#  'little': 4,
#  'afore': 5,
#  'quality': 6,
#  'shield': 7,
#  'car': 8,
#  'committed': 9,
#  'tribe': 10,
#  'present': 11,
#  'keep': 12,
#  'endless': 13,
#  'draperies': 14,
#  'spy': 15,
#  'impunity': 16,
#  'would': 17,
#  'flowing': 18,
#  'rem': 19,
#  'fairly': 20,
#  'chance': 21,
#  'glen': 22,
#  'out': 23,
#  'met': 24,
#  'let': 25,
#  'time': 26,
#  'noble': 27,
#  'amidst': 28,
#  'provided': 29,
#  'genial': 30,
#  'have': 31,
#  'sputer': 32,
#  'we': 33,
#  'warriors': 34,
#  'breath': 35,
#  'mouth': 36,
#  'knew': 37,
#  'before': 38,
#  'courage': 39,
#  'better': 40,
#  'conning': 41,
#  'moved': 42,
#  'certainly': 43,
#  'verge': 44,
#  'near': 45,
#  'finding': 46,
#  'bursts': 47,
#  'make': 48,
#  'nose': 49,
#  'obedience': 50,
#  'kep': 51,
#  'changes': 52,
#  'paleness': 53,
#  'dyin': 54,
#  'he': 55,
#  'wiliam': 56,
#  'states': 57,
#  'murdered': 58,
#  'kind': 59,
#  'without': 60,
#  'extravagant': 61,
#  'blueberry': 62,
#  'boats': 63,
#  'parts': 64,
#  'box': 65,
#  'often': 66,
#  'magazine': 67,
#  'beauty': 68,
#  'each': 69,
#  'ultimate': 70,
#  'birth': 71,
#  'not': 72,
#  'helples': 73,
#  'facial': 74,
#  'water': 75,
#  'galopin': 76,
#  'state': 77,
#  'wig': 78,
#  'gentle': 79,
#  'daown': 80,
#  'gently': 81,
#  'friendship': 82,
#  'moments': 83,
#  'wars': 84,
#  'exist': 85,
#  'cold': 86,
#  'california': 87,
#  'get': 88,
#  'must': 89,
#  'neither': 90,
#  'evening': 91,
#  'youth': 92,
#  'a': 93,
#  'shade': 94,
#  'wildest': 95,
#  'pigeons': 96,
#  'various': 97,
#  'bushes': 98,
#  'absolutely': 99,
#  'gauges': 100,
#  'conducted': 101,
#  'energy': 102,
#  'breakers': 103,
#  'prints': 104,
#  'concealed': 105,
#  'drest': 106,
#  'destruction': 107,
#  'cast': 108,
#  'sounds': 109,
#  'plane': 110,
#  'mnar': 111,
#  'plague': 112,
#  'marched': 113,
#  'ever': 114,
#  'ago': 115,
#  'instruments': 116,
#  'monday': 117,
#  'condition': 118,
#  'wide': 119,
#  'known': 120,
#  'how': 121,
#  'clammy': 122,
#  'place': 123,
#  'lie': 124,
#  'pursue': 125,
#  'dizzily': 126,
#  'muscular': 127,
#  'geneva': 128,
#  'rudimentary': 129,
#  'peculiar': 130,
#  'fantastic': 131,
#  'window': 132,
#  'brutality': 133,
#  'interior': 134,
#  'exceeding': 135,
#  'piteously': 136,
#  'presumably': 137,
#  'point': 138,
#  'desk': 139,
#  'modern': 140,
#  'apparently': 141,
#  'under': 142,
#  'underduk': 143,
#  'cared': 144,
#  'table': 145,
#  'vilages': 146,
#  'distressed': 147,
#  'profesors': 148,
#  'delivered': 149,
#  'turned': 150,
#  'henceforth': 151,
#  'ib': 152,
#  'winter': 153,
#  'exercised': 154,
#  'peak': 155,
#  'far': 156,
#  'oriels': 157,
#  'academy': 158,
#  'rheumatism': 159,
#  'four': 160,
#  'believed': 161,
#  'events': 162,
#  'about': 163,
#  'player': 164,
#  'draconian': 165,
#  'unable': 166,
#  'cat': 167,
#  'greks': 168,
#  'board': 169,
#  'children': 170,
#  'degree': 171,
#  'perhaps': 172,
#  'love': 173,
#  'elipse': 174,
#  'course': 175,
#  'word': 176,
#  'gout': 177,
#  'gained': 178,
#  'names': 179,
#  'length': 180,
#  'sent': 181,
#  'being': 182,
#  'maternal': 183,
#  'flight': 184,
#  'galery': 185,
#  'journey': 186,
#  'deep': 187,
#  'abandoned': 188,
#  'fast': 189,
#  'either': 190,
#  'hardly': 191,
#  'foot': 192,
#  'atomies': 193,
#  'orion': 194,
#  'friend': 195,
#  'your': 196,
#  'precociously': 197,
#  'visit': 198,
#  'end': 199,
#  'spent': 200,
#  'decisive': 201,
#  'hereditary': 202,
#  'changing': 203,
#  'nebula': 204,
#  'up': 205,
#  'carefully': 206,
#  'staggered': 207,
#  'united': 208,
#  'tower': 209,
#  'protecting': 210,
#  'alarm': 211,
#  'portrait': 212,
#  'step': 213,
#  'von': 214,
#  'selfish': 215,
#  'heard': 216,
#  'fever': 217,
#  'pots': 218,
#  'attractions': 219,
#  'details': 220,
#  'beheld': 221,
#  'gods': 222,
#  'astronomer': 223,
#  'taken': 224,
#  'slightly': 225,
#  'else': 226,
#  'diminution': 227,
#  'branch': 228,
#  'vague': 229,
#  'companionles': 230,
#  'back': 231,
#  'ear': 232,
#  'calendar': 233,
#  'world': 234,
#  'sick': 235,
#  'ful': 236,
#  'on': 237,
#  'more': 238,
#  'verandas': 239,
#  'wipin': 240,
#  'people': 241,
#  'ailments': 242,
#  'whereupon': 243,
#  'its': 244,
#  'difficulty': 245,
#  'spreading': 246,
#  'view': 247,
#  'best': 248,
#  'come': 249,
#  'courtyard': 250,
#  'consideration': 251,
#  'carved': 252,
#  'signs': 253,
#  'wings': 254,
#  'bed': 255,
#  'protection': 256,
#  'crag': 257,
#  'seemed': 258,
#  'counties': 259,
#  'symphonic': 260,
#  'flux': 261,
#  'hoped': 262,
#  'pages': 263,
#  'confess': 264,
#  'they': 265,
#  'continued': 266,
#  'hitherto': 267,
#  'contented': 268,
#  'powdered': 269,
#  'late': 270,
#  'prohibited': 271,
#  'sign': 272,
#  'grey': 273,
#  'girl': 274,
#  'clouds': 275,
#  'legrand': 276,
#  'court': 277,
#  'persons': 278,
#  'quantities': 279,
#  'fal': 280,
#  'most': 281,
#  'd': 282,
#  'you': 283,
#  'from': 284,
#  'dr': 285,
#  'surrounding': 286,
#  'tormentors': 287,
#  'defended': 288,
#  'enthusiasm': 289,
#  'siege': 290,
#  'decreased': 291,
#  'lately': 292,
#  'inevitably': 293,
#  'silent': 294,
#  'remember': 295,
#  'owed': 296,
#  'administered': 297,
#  'based': 298,
#  'demurely': 299,
#  'succeeded': 300,
#  'shouldst': 301,
#  'coming': 302,
#  'sour': 303,
#  'three': 304,
#  'teach': 305,
#  'dampness': 306,
#  'them': 307,
#  'change': 308,
#  'notice': 309,
#  'listened': 310,
#  'characteristicaly': 311,
#  'there': 312,
#  'defeat': 313,
#  'conquered': 314,
#  'replaced': 315,
#  'ply': 316,
#  'unite': 317,
#  'rather': 318,
#  'feline': 319,
#  'wonder': 320,
#  'followed': 321,
#  'cotage': 322,
#  'fancying': 323,
#  'expression': 324,
#  'like': 325,
#  'relation': 326,
#  'affairs': 327,
#  'information': 328,
#  'structure': 329,
#  'slow': 330,
#  'tombs': 331,
#  'thinking': 332,
#  'eyes': 333,
#  'snake': 334,
#  'necesary': 335,
#  'that': 336,
#  'his': 337,
#  'big': 338,
#  'at': 339,
#  'referring': 340,
#  'still': 341,
#  'however': 342,
#  'ancient': 343,
#  'sold': 344,
#  'reckoning': 345,
#  'chronic': 346,
#  'snuff': 347,
#  'involved': 348,
#  'down': 349,
#  'marble': 350,
#  'few': 351,
#  'really': 352,
#  'took': 353,
#  'waves': 354,
#  'wil': 355,
#  'star': 356,
#  'threw': 357,
#  'dim': 358,
#  'in': 359,
#  'sprightliness': 360,
#  'wilderness': 361,
#  'care': 362,
#  'busy': 363,
#  'bras': 364,
#  'whirlpool': 365,
#  'progress': 366,
#  'greatest': 367,
#  'thing': 368,
#  'perplexity': 369,
#  'man': 370,
#  'trifle': 371,
#  'buls': 372,
#  'fatality': 373,
#  'case': 374,
#  'pulpit': 375,
#  'got': 376,
#  'inconvenient': 377,
#  'all': 378,
#  'great': 379,
#  'longer': 380,
#  'might': 381,
#  'well': 382,
#  'paid': 383,
#  'commence': 384,
#  'shared': 385,
#  'over': 386,
#  'weakness': 387,
#  'capered': 388,
#  'secure': 389,
#  'appeared': 390,
#  'system': 391,
#  'sharp': 392,
#  'demoniac': 393,
#  'islanders': 394,
#  'mothers': 395,
#  'panes': 396,
#  'overflowed': 397,
#  'beginning': 398,
#  'roofs': 399,
#  'year': 400,
#  'inteligence': 401,
#  'numbers': 402,
#  'appointed': 403,
#  'upon': 404,
#  'rom': 405,
#  'into': 406,
#  'overcome': 407,
#  'suddenly': 408,
#  'mariner': 409,
#  'cloaks': 410,
#  'said': 411,
#  'looked': 412,
#  'everybody': 413,
#  'arnheim': 414,
#  'ide': 415,
#  'inquiries': 416,
#  'resolved': 417,
#  'newcomers': 418,
#  'general': 419,
#  'metal': 420,
#  'dared': 421,
#  'suposed': 422,
#  'grass': 423,
#  'be': 424,
#  'excitement': 425,
#  'incessantly': 426,
#  'safety': 427,
#  'sea': 428,
#  'discovery': 429,
#  'morning': 430,
#  'profesion': 431,
#  'influence': 432,
#  'one': 433,
#  'paradise': 434,
#  'contain': 435,
#  'find': 436,
#  'minarets': 437,
#  'those': 438,
#  'singularly': 439,
#  'the': 440,
#  'naked': 441,
#  'since': 442,
#  'became': 443,
#  'vibrations': 444,
#  'pew': 445,
#  'atrophied': 446,
#  'ascended': 447,
#  'assumed': 448,
#  'clericaly': 449,
#  'noted': 450,
#  'stood': 451,
#  'nearly': 452,
#  'did': 453,
#  'rested': 454,
#  'remarkable': 455,
#  'globe': 456,
#  'produced': 457,
#  'say': 458,
#  'constantinople': 459,
#  'whole': 460,
#  'lead': 461,
#  'afterward': 462,
#  'interest': 463,
#  'reflection': 464,
#  'away': 465,
#  'ferule': 466,
#  'wont': 467,
#  'first': 468,
#  'aperture': 469,
#  'fumes': 470,
#  'escape': 471,
#  'ocean': 472,
#  'awhile': 473,
#  'now': 474,
#  'services': 475,
#  'acting': 476,
#  'some': 477,
#  'exhaling': 478,
#  'matter': 479,
#  'troubled': 480,
#  'cutting': 481,
#  'outside': 482,
#  'western': 483,
#  'air': 484,
#  'devoted': 485,
#  'start': 486,
#  'mountainous': 487,
#  'us': 488,
#  'suggestion': 489,
#  'light': 490,
#  'reposed': 491,
#  'feel': 492,
#  'who': 493,
#  'take': 494,
#  'results': 495,
#  'nebular': 496,
#  'found': 497,
#  'introduction': 498,
#  'placed': 499,
#  'will': 500,
#  'tissue': 501,
#  'long': 502,
#  'seen': 503,
#  'shehan': 504,
#  'governments': 505,
#  'discernible': 506,
#  'centre': 507,
#  'largest': 508,
#  'thoughts': 509,
#  'suffered': 510,
#  'palor': 511,
#  'posesion': 512,
#  'left': 513,
#  'whar': 514,
#  'barricaded': 515,
#  'concerning': 516,
#  'pure': 517,
#  'cosmogony': 518,
#  'wilburs': 519,
#  'sufficiently': 520,
#  'my': 521,
#  'declivity': 522,
#  'themselves': 523,
#  'stone': 524,
#  'it': 525,
#  'portholes': 526,
#  'hideous': 527,
#  'struggle': 528,
#  'pestilence': 529,
#  'side': 530,
#  'other': 531,
#  'sits': 532,
#  'road': 533,
#  'hours': 534,
#  'top': 535,
#  'luminosity': 536,
#  'limit': 537,
#  'maouth': 538,
#  'faces': 539,
#  'theories': 540,
#  'spot': 541,
#  'benign': 542,
#  'war': 543,
#  'or': 544,
#  'old': 545,
#  'tracks': 546,
#  'tremendous': 547,
#  'any': 548,
#  'nor': 549,
#  'value': 550,
#  'which': 551,
#  'give': 552,
#  'sustain': 553,
#  'another': 554,
#  'below': 555,
#  'made': 556,
#  'ardent': 557,
#  'g': 558,
#  'survive': 559,
#  'presently': 560,
#  'greatly': 561,
#  'remote': 562,
#  'especially': 563,
#  'destructive': 564,
#  'these': 565,
#  'through': 566,
#  'upward': 567,
#  'tell': 568,
#  'canot': 569,
#  'windows': 570,
#  'i': 571,
#  'remembrance': 572,
#  'usually': 573,
#  'chimney': 574,
#  'poor': 575,
#  'sky': 576,
#  'forrad': 577,
#  'cut': 578,
#  'politics': 579,
#  'me': 580,
#  'getting': 581,
#  'johnson': 582,
#  'phenomenal': 583,
#  'minded': 584,
#  'only': 585,
#  'came': 586,
#  'document': 587,
#  'atmosphere': 588,
#  'lieutenant': 589,
#  'track': 590,
#  'victory': 591,
#  'soul': 592,
#  'hil': 593,
#  'inhabitants': 594,
#  'leadership': 595,
#  'when': 596,
#  'had': 597,
#  'somethin': 598,
#  'nothing': 599,
#  'fantastically': 600,
#  'across': 601,
#  'times': 602,
#  'raising': 603,
#  'unrelenting': 604,
#  'principal': 605,
#  'pointed': 606,
#  'canoe': 607,
#  'hesitate': 608,
#  'unknown': 609,
#  'furniture': 610,
#  'earth': 611,
#  'affection': 612,
#  'rest': 613,
#  'substances': 614,
#  'intervals': 615,
#  'pausing': 616,
#  'kempelens': 617,
#  'studies': 618,
#  'greek': 619,
#  'generate': 620,
#  'thin': 621,
#  'remained': 622,
#  'desirous': 623,
#  'hand': 624,
#  'queer': 625,
#  'escaped': 626,
#  'disclosing': 627,
#  'contraction': 628,
#  'hectic': 629,
#  'has': 630,
#  'vain': 631,
#  'nigh': 632,
#  'gasped': 633,
#  'struggled': 634,
#  'self': 635,
#  'rich': 636,
#  'what': 637,
#  'analogy': 638,
#  'visits': 639,
#  'quivering': 640,
#  'island': 641,
#  'increase': 642,
#  'just': 643,
#  'connection': 644,
#  'phrase': 645,
#  'sunny': 646,
#  'able': 647,
#  'combat': 648,
#  'arter': 649,
#  'ruined': 650,
#  'firm': 651,
#  'size': 652,
#  'solemn': 653,
#  'speculation': 654,
#  'intrigues': 655,
#  'objects': 656,
#  'latin': 657,
#  'brow': 658,
#  'vestiges': 659,
#  'spread': 660,
#  'nature': 661,
#  'occasionally': 662,
#  'childrens': 663,
#  'snufy': 664,
#  'exultation': 665,
#  'meantime': 666,
#  'within': 667,
#  'spirit': 668,
#  'poison': 669,
#  'endure': 670,
#  'oh': 671,
#  'steps': 672,
#  'al': 673,
#  'almost': 674,
#  'shone': 675,
#  'after': 676,
#  'avoid': 677,
#  'means': 678,
#  'disapeared': 679,
#  'hope': 680,
#  'look': 681,
#  'nedles': 682,
#  'evidently': 683,
#  'imagination': 684,
#  'faded': 685,
#  'talked': 686,
#  'eastward': 687,
#  'want': 688,
#  'albertus': 689,
#  'respect': 690,
#  'where': 691,
#  'native': 692,
#  'ill': 693,
#  'impertinence': 694,
#  'o': 695,
#  'her': 696,
#  'never': 697,
#  'accustomed': 698,
#  'gave': 699,
#  'here': 700,
#  'thus': 701,
#  'accession': 702,
#  'casting': 703,
#  'grandfathers': 704,
#  'southern': 705,
#  'conclusion': 706,
#  'sparse': 707,
#  'proportions': 708,
#  'glare': 709,
#  'merival': 710,
#  'compases': 711,
#  'shrank': 712,
#  'wel': 713,
#  'even': 714,
#  'wonderful': 715,
#  'woe': 716,
#  'drift': 717,
#  'every': 718,
#  'climate': 719,
#  'understand': 720,
#  'immediate': 721,
#  'speeches': 722,
#  'trees': 723,
#  'torch': 724,
#  'an': 725,
#  'full': 726,
#  'ship': 727,
#  'minutely': 728,
#  'went': 729,
#  'unrecognised': 730,
#  'looking': 731,
#  'scant': 732,
#  'do': 733,
#  'intense': 734,
#  'deserted': 735,
#  'agripa': 736,
#  'beginin': 737,
#  'satisfaction': 738,
#  'collecting': 739,
#  'superintendent': 740,
#  'rendered': 741,
#  'panted': 742,
#  'organs': 743,
#  'country': 744,
#  'fro': 745,
#  'loved': 746,
#  'suggesting': 747,
#  'mewed': 748,
#  'infants': 749,
#  'building': 750,
#  'doubt': 751,
#  'underwent': 752,
#  'balconies': 753,
#  'pased': 754,
#  'men': 755,
#  'interment': 756,
#  'set': 757,
#  'abruptly': 758,
#  'prodigies': 759,
#  'disagreeable': 760,
#  'fire': 761,
#  'mud': 762,
#  'years': 763,
#  'very': 764,
#  'by': 765,
#  'shrines': 766,
#  'letters': 767,
#  'quasi': 768,
#  'raymond': 769,
#  'celebrated': 770,
#  'visibly': 771,
#  'traced': 772,
#  'age': 773,
#  'simply': 774,
#  'feminine': 775,
#  'secret': 776,
#  'season': 777,
#  'week': 778,
#  'two': 779,
#  'prophecies': 780,
#  'reverend': 781,
#  'behind': 782,
#  'thy': 783,
#  'than': 784,
#  'scrub': 785,
#  'stereotomy': 786,
#  'rain': 787,
#  'mobile': 788,
#  'maturity': 789,
#  'possessed': 790,
#  'fell': 791,
#  'but': 792,
#  'thou': 793,
#  'part': 794,
#  'windsor': 795,
#  'character': 796,
#  'him': 797,
#  'excep': 798,
#  'among': 799,
#  'refined': 800,
#  'bit': 801,
#  'again': 802,
#  'refuge': 803,
#  'discussed': 804,
#  'inopportuneness': 805,
#  'growth': 806,
#  'months': 807,
#  'ahead': 808,
#  'land': 809,
#  'attained': 810,
#  'judged': 811,
#  'observed': 812,
#  'doors': 813,
#  'room': 814,
#  'guesses': 815,
#  'wondrous': 816,
#  'confirmation': 817,
#  'lips': 818,
#  'many': 819,
#  'depth': 820,
#  'increased': 821,
#  'manner': 822,
#  'foaming': 823,
#  'epicurus': 824,
#  'constantly': 825,
#  'thoughtless': 826,
#  'aout': 827,
#  'countenance': 828,
#  'dilation': 829,
#  'bugs': 830,
#  'machine': 831,
#  'analysis': 832,
#  'serene': 833,
#  'pass': 834,
#  'glowing': 835,
#  'quartered': 836,
#  'act': 837,
#  'sunk': 838,
#  'date': 839,
#  'somewhat': 840,
#  'unsteady': 841,
#  'undue': 842,
#  'preternatural': 843,
#  'horizon': 844,
#  'speak': 845,
#  'could': 846,
#  'equal': 847,
#  'so': 848,
#  'violence': 849,
#  'delicate': 850,
#  'expenses': 851,
#  'paracelsus': 852,
#  'nets': 853,
#  'readily': 854,
#  'power': 855,
#  'regard': 856,
#  'cough': 857,
#  'myself': 858,
#  'eliciting': 859,
#  'been': 860,
#  'door': 861,
#  'should': 862,
#  'non': 863,
#  'struck': 864,
#  'grew': 865,
#  'languages': 866,
#  'cud': 867,
#  'passed': 868,
#  'symbol': 869,
#  'rock': 870,
#  'barls': 871,
#  'abaout': 872,
#  'expected': 873,
#  'unpleasant': 874,
#  'while': 875,
#  'laws': 876,
#  'availability': 877,
#  'engulfed': 878,
#  'placid': 879,
#  'heart': 880,
#  'pursy': 881,
#  'render': 882,
#  'pupils': 883,
#  'interpretation': 884,
#  'swiftly': 885,
#  'bite': 886,
#  'dare': 887,
#  'revealed': 888,
#  'adulthood': 889,
#  'twinge': 890,
#  'design': 891,
#  'importance': 892,
#  'aspect': 893,
#  'conceive': 894,
#  'disinclined': 895,
#  'desires': 896,
#  'chinlesnes': 897,
#  'society': 898,
#  'needed': 899,
#  'till': 900,
#  'equally': 901,
#  'lords': 902,
#  'herself': 903,
#  'frequent': 904,
#  'sarnath': 905,
#  'no': 906,
#  'next': 907,
#  'peculiarly': 908,
#  'money': 909,
#  'own': 910,
#  'itself': 911,
#  'ices': 912,
#  'think': 913,
#  'beings': 914,
#  'to': 915,
#  'such': 916,
#  'kindliness': 917,
#  'advancement': 918,
#  'madly': 919,
#  'guardian': 920,
#  'sense': 921,
#  'was': 922,
#  'horrible': 923,
#  'fet': 924,
#  'revived': 925,
#  'with': 926,
#  'extreme': 927,
#  'enabled': 928,
#  'is': 929,
#  'sacrifices': 930,
#  'watches': 931,
#  'shaped': 932,
#  'comprehension': 933,
#  'sordidness': 934,
#  'certain': 935,
#  'off': 936,
#  'were': 937,
#  'terific': 938,
#  'and': 939,
#  'steals': 940,
#  'held': 941,
#  'wrapping': 942,
#  'dark': 943,
#  'murmur': 944,
#  'yet': 945,
#  'cornelius': 946,
#  'fanciful': 947,
#  'developments': 948,
#  'can': 949,
#  'exclamations': 950,
#  'abroad': 951,
#  'habiliments': 952,
#  'heavy': 953,
#  'ample': 954,
#  'magnus': 955,
#  'this': 956,
#  'blankets': 957,
#  'around': 958,
#  'beyond': 959,
#  'sun': 960,
#  'ready': 961,
#  'cel': 962,
#  'sole': 963,
#  'disadvantages': 964,
#  'brought': 965,
#  'eye': 966,
#  'possible': 967,
#  'our': 968,
#  'brings': 969,
#  'for': 970,
#  'rigid': 971,
#  'caused': 972,
#  'follow': 973,
#  'conquest': 974,
#  'apparent': 975,
#  'mentioned': 976,
#  'glory': 977,
#  'usual': 978,
#  'idea': 979,
#  'as': 980,
#  'overthrow': 981,
#  'if': 982,
#  'of': 983,
#  'she': 984,
#  'afections': 985,
#  'young': 986,
#  'yourself': 987,
#  'robes': 988,
#  'carcas': 989,
#  'groundwork': 990,
#  'descended': 991,
#  'enterprise': 992,
#  'crew': 993,
#  'solitude': 994,
#  'brink': 995,
#  'scheme': 996,
#  'code': 997,
#  'surface': 998,
#  'distaste': 999,
#  ...}

# %%
idx2word = {i: word for word, i in word2idx.items()}
idx2word
# Out:
# {0: 'slovenly',
#  1: 'atempts',
#  2: 'calamity',
#  3: 'gold',
#  4: 'little',
#  5: 'afore',
#  6: 'quality',
#  7: 'shield',
#  8: 'car',
#  9: 'committed',
#  10: 'tribe',
#  11: 'present',
#  12: 'keep',
#  13: 'endless',
#  14: 'draperies',
#  15: 'spy',
#  16: 'impunity',
#  17: 'would',
#  18: 'flowing',
#  19: 'rem',
#  20: 'fairly',
#  21: 'chance',
#  22: 'glen',
#  23: 'out',
#  24: 'met',
#  25: 'let',
#  26: 'time',
#  27: 'noble',
#  28: 'amidst',
#  29: 'provided',
#  30: 'genial',
#  31: 'have',
#  32: 'sputer',
#  33: 'we',
#  34: 'warriors',
#  35: 'breath',
#  36: 'mouth',
#  37: 'knew',
#  38: 'before',
#  39: 'courage',
#  40: 'better',
#  41: 'conning',
#  42: 'moved',
#  43: 'certainly',
#  44: 'verge',
#  45: 'near',
#  46: 'finding',
#  47: 'bursts',
#  48: 'make',
#  49: 'nose',
#  50: 'obedience',
#  51: 'kep',
#  52: 'changes',
#  53: 'paleness',
#  54: 'dyin',
#  55: 'he',
#  56: 'wiliam',
#  57: 'states',
#  58: 'murdered',
#  59: 'kind',
#  60: 'without',
#  61: 'extravagant',
#  62: 'blueberry',
#  63: 'boats',
#  64: 'parts',
#  65: 'box',
#  66: 'often',
#  67: 'magazine',
#  68: 'beauty',
#  69: 'each',
#  70: 'ultimate',
#  71: 'birth',
#  72: 'not',
#  73: 'helples',
#  74: 'facial',
#  75: 'water',
#  76: 'galopin',
#  77: 'state',
#  78: 'wig',
#  79: 'gentle',
#  80: 'daown',
#  81: 'gently',
#  82: 'friendship',
#  83: 'moments',
#  84: 'wars',
#  85: 'exist',
#  86: 'cold',
#  87: 'california',
#  88: 'get',
#  89: 'must',
#  90: 'neither',
#  91: 'evening',
#  92: 'youth',
#  93: 'a',
#  94: 'shade',
#  95: 'wildest',
#  96: 'pigeons',
#  97: 'various',
#  98: 'bushes',
#  99: 'absolutely',
#  100: 'gauges',
#  101: 'conducted',
#  102: 'energy',
#  103: 'breakers',
#  104: 'prints',
#  105: 'concealed',
#  106: 'drest',
#  107: 'destruction',
#  108: 'cast',
#  109: 'sounds',
#  110: 'plane',
#  111: 'mnar',
#  112: 'plague',
#  113: 'marched',
#  114: 'ever',
#  115: 'ago',
#  116: 'instruments',
#  117: 'monday',
#  118: 'condition',
#  119: 'wide',
#  120: 'known',
#  121: 'how',
#  122: 'clammy',
#  123: 'place',
#  124: 'lie',
#  125: 'pursue',
#  126: 'dizzily',
#  127: 'muscular',
#  128: 'geneva',
#  129: 'rudimentary',
#  130: 'peculiar',
#  131: 'fantastic',
#  132: 'window',
#  133: 'brutality',
#  134: 'interior',
#  135: 'exceeding',
#  136: 'piteously',
#  137: 'presumably',
#  138: 'point',
#  139: 'desk',
#  140: 'modern',
#  141: 'apparently',
#  142: 'under',
#  143: 'underduk',
#  144: 'cared',
#  145: 'table',
#  146: 'vilages',
#  147: 'distressed',
#  148: 'profesors',
#  149: 'delivered',
#  150: 'turned',
#  151: 'henceforth',
#  152: 'ib',
#  153: 'winter',
#  154: 'exercised',
#  155: 'peak',
#  156: 'far',
#  157: 'oriels',
#  158: 'academy',
#  159: 'rheumatism',
#  160: 'four',
#  161: 'believed',
#  162: 'events',
#  163: 'about',
#  164: 'player',
#  165: 'draconian',
#  166: 'unable',
#  167: 'cat',
#  168: 'greks',
#  169: 'board',
#  170: 'children',
#  171: 'degree',
#  172: 'perhaps',
#  173: 'love',
#  174: 'elipse',
#  175: 'course',
#  176: 'word',
#  177: 'gout',
#  178: 'gained',
#  179: 'names',
#  180: 'length',
#  181: 'sent',
#  182: 'being',
#  183: 'maternal',
#  184: 'flight',
#  185: 'galery',
#  186: 'journey',
#  187: 'deep',
#  188: 'abandoned',
#  189: 'fast',
#  190: 'either',
#  191: 'hardly',
#  192: 'foot',
#  193: 'atomies',
#  194: 'orion',
#  195: 'friend',
#  196: 'your',
#  197: 'precociously',
#  198: 'visit',
#  199: 'end',
#  200: 'spent',
#  201: 'decisive',
#  202: 'hereditary',
#  203: 'changing',
#  204: 'nebula',
#  205: 'up',
#  206: 'carefully',
#  207: 'staggered',
#  208: 'united',
#  209: 'tower',
#  210: 'protecting',
#  211: 'alarm',
#  212: 'portrait',
#  213: 'step',
#  214: 'von',
#  215: 'selfish',
#  216: 'heard',
#  217: 'fever',
#  218: 'pots',
#  219: 'attractions',
#  220: 'details',
#  221: 'beheld',
#  222: 'gods',
#  223: 'astronomer',
#  224: 'taken',
#  225: 'slightly',
#  226: 'else',
#  227: 'diminution',
#  228: 'branch',
#  229: 'vague',
#  230: 'companionles',
#  231: 'back',
#  232: 'ear',
#  233: 'calendar',
#  234: 'world',
#  235: 'sick',
#  236: 'ful',
#  237: 'on',
#  238: 'more',
#  239: 'verandas',
#  240: 'wipin',
#  241: 'people',
#  242: 'ailments',
#  243: 'whereupon',
#  244: 'its',
#  245: 'difficulty',
#  246: 'spreading',
#  247: 'view',
#  248: 'best',
#  249: 'come',
#  250: 'courtyard',
#  251: 'consideration',
#  252: 'carved',
#  253: 'signs',
#  254: 'wings',
#  255: 'bed',
#  256: 'protection',
#  257: 'crag',
#  258: 'seemed',
#  259: 'counties',
#  260: 'symphonic',
#  261: 'flux',
#  262: 'hoped',
#  263: 'pages',
#  264: 'confess',
#  265: 'they',
#  266: 'continued',
#  267: 'hitherto',
#  268: 'contented',
#  269: 'powdered',
#  270: 'late',
#  271: 'prohibited',
#  272: 'sign',
#  273: 'grey',
#  274: 'girl',
#  275: 'clouds',
#  276: 'legrand',
#  277: 'court',
#  278: 'persons',
#  279: 'quantities',
#  280: 'fal',
#  281: 'most',
#  282: 'd',
#  283: 'you',
#  284: 'from',
#  285: 'dr',
#  286: 'surrounding',
#  287: 'tormentors',
#  288: 'defended',
#  289: 'enthusiasm',
#  290: 'siege',
#  291: 'decreased',
#  292: 'lately',
#  293: 'inevitably',
#  294: 'silent',
#  295: 'remember',
#  296: 'owed',
#  297: 'administered',
#  298: 'based',
#  299: 'demurely',
#  300: 'succeeded',
#  301: 'shouldst',
#  302: 'coming',
#  303: 'sour',
#  304: 'three',
#  305: 'teach',
#  306: 'dampness',
#  307: 'them',
#  308: 'change',
#  309: 'notice',
#  310: 'listened',
#  311: 'characteristicaly',
#  312: 'there',
#  313: 'defeat',
#  314: 'conquered',
#  315: 'replaced',
#  316: 'ply',
#  317: 'unite',
#  318: 'rather',
#  319: 'feline',
#  320: 'wonder',
#  321: 'followed',
#  322: 'cotage',
#  323: 'fancying',
#  324: 'expression',
#  325: 'like',
#  326: 'relation',
#  327: 'affairs',
#  328: 'information',
#  329: 'structure',
#  330: 'slow',
#  331: 'tombs',
#  332: 'thinking',
#  333: 'eyes',
#  334: 'snake',
#  335: 'necesary',
#  336: 'that',
#  337: 'his',
#  338: 'big',
#  339: 'at',
#  340: 'referring',
#  341: 'still',
#  342: 'however',
#  343: 'ancient',
#  344: 'sold',
#  345: 'reckoning',
#  346: 'chronic',
#  347: 'snuff',
#  348: 'involved',
#  349: 'down',
#  350: 'marble',
#  351: 'few',
#  352: 'really',
#  353: 'took',
#  354: 'waves',
#  355: 'wil',
#  356: 'star',
#  357: 'threw',
#  358: 'dim',
#  359: 'in',
#  360: 'sprightliness',
#  361: 'wilderness',
#  362: 'care',
#  363: 'busy',
#  364: 'bras',
#  365: 'whirlpool',
#  366: 'progress',
#  367: 'greatest',
#  368: 'thing',
#  369: 'perplexity',
#  370: 'man',
#  371: 'trifle',
#  372: 'buls',
#  373: 'fatality',
#  374: 'case',
#  375: 'pulpit',
#  376: 'got',
#  377: 'inconvenient',
#  378: 'all',
#  379: 'great',
#  380: 'longer',
#  381: 'might',
#  382: 'well',
#  383: 'paid',
#  384: 'commence',
#  385: 'shared',
#  386: 'over',
#  387: 'weakness',
#  388: 'capered',
#  389: 'secure',
#  390: 'appeared',
#  391: 'system',
#  392: 'sharp',
#  393: 'demoniac',
#  394: 'islanders',
#  395: 'mothers',
#  396: 'panes',
#  397: 'overflowed',
#  398: 'beginning',
#  399: 'roofs',
#  400: 'year',
#  401: 'inteligence',
#  402: 'numbers',
#  403: 'appointed',
#  404: 'upon',
#  405: 'rom',
#  406: 'into',
#  407: 'overcome',
#  408: 'suddenly',
#  409: 'mariner',
#  410: 'cloaks',
#  411: 'said',
#  412: 'looked',
#  413: 'everybody',
#  414: 'arnheim',
#  415: 'ide',
#  416: 'inquiries',
#  417: 'resolved',
#  418: 'newcomers',
#  419: 'general',
#  420: 'metal',
#  421: 'dared',
#  422: 'suposed',
#  423: 'grass',
#  424: 'be',
#  425: 'excitement',
#  426: 'incessantly',
#  427: 'safety',
#  428: 'sea',
#  429: 'discovery',
#  430: 'morning',
#  431: 'profesion',
#  432: 'influence',
#  433: 'one',
#  434: 'paradise',
#  435: 'contain',
#  436: 'find',
#  437: 'minarets',
#  438: 'those',
#  439: 'singularly',
#  440: 'the',
#  441: 'naked',
#  442: 'since',
#  443: 'became',
#  444: 'vibrations',
#  445: 'pew',
#  446: 'atrophied',
#  447: 'ascended',
#  448: 'assumed',
#  449: 'clericaly',
#  450: 'noted',
#  451: 'stood',
#  452: 'nearly',
#  453: 'did',
#  454: 'rested',
#  455: 'remarkable',
#  456: 'globe',
#  457: 'produced',
#  458: 'say',
#  459: 'constantinople',
#  460: 'whole',
#  461: 'lead',
#  462: 'afterward',
#  463: 'interest',
#  464: 'reflection',
#  465: 'away',
#  466: 'ferule',
#  467: 'wont',
#  468: 'first',
#  469: 'aperture',
#  470: 'fumes',
#  471: 'escape',
#  472: 'ocean',
#  473: 'awhile',
#  474: 'now',
#  475: 'services',
#  476: 'acting',
#  477: 'some',
#  478: 'exhaling',
#  479: 'matter',
#  480: 'troubled',
#  481: 'cutting',
#  482: 'outside',
#  483: 'western',
#  484: 'air',
#  485: 'devoted',
#  486: 'start',
#  487: 'mountainous',
#  488: 'us',
#  489: 'suggestion',
#  490: 'light',
#  491: 'reposed',
#  492: 'feel',
#  493: 'who',
#  494: 'take',
#  495: 'results',
#  496: 'nebular',
#  497: 'found',
#  498: 'introduction',
#  499: 'placed',
#  500: 'will',
#  501: 'tissue',
#  502: 'long',
#  503: 'seen',
#  504: 'shehan',
#  505: 'governments',
#  506: 'discernible',
#  507: 'centre',
#  508: 'largest',
#  509: 'thoughts',
#  510: 'suffered',
#  511: 'palor',
#  512: 'posesion',
#  513: 'left',
#  514: 'whar',
#  515: 'barricaded',
#  516: 'concerning',
#  517: 'pure',
#  518: 'cosmogony',
#  519: 'wilburs',
#  520: 'sufficiently',
#  521: 'my',
#  522: 'declivity',
#  523: 'themselves',
#  524: 'stone',
#  525: 'it',
#  526: 'portholes',
#  527: 'hideous',
#  528: 'struggle',
#  529: 'pestilence',
#  530: 'side',
#  531: 'other',
#  532: 'sits',
#  533: 'road',
#  534: 'hours',
#  535: 'top',
#  536: 'luminosity',
#  537: 'limit',
#  538: 'maouth',
#  539: 'faces',
#  540: 'theories',
#  541: 'spot',
#  542: 'benign',
#  543: 'war',
#  544: 'or',
#  545: 'old',
#  546: 'tracks',
#  547: 'tremendous',
#  548: 'any',
#  549: 'nor',
#  550: 'value',
#  551: 'which',
#  552: 'give',
#  553: 'sustain',
#  554: 'another',
#  555: 'below',
#  556: 'made',
#  557: 'ardent',
#  558: 'g',
#  559: 'survive',
#  560: 'presently',
#  561: 'greatly',
#  562: 'remote',
#  563: 'especially',
#  564: 'destructive',
#  565: 'these',
#  566: 'through',
#  567: 'upward',
#  568: 'tell',
#  569: 'canot',
#  570: 'windows',
#  571: 'i',
#  572: 'remembrance',
#  573: 'usually',
#  574: 'chimney',
#  575: 'poor',
#  576: 'sky',
#  577: 'forrad',
#  578: 'cut',
#  579: 'politics',
#  580: 'me',
#  581: 'getting',
#  582: 'johnson',
#  583: 'phenomenal',
#  584: 'minded',
#  585: 'only',
#  586: 'came',
#  587: 'document',
#  588: 'atmosphere',
#  589: 'lieutenant',
#  590: 'track',
#  591: 'victory',
#  592: 'soul',
#  593: 'hil',
#  594: 'inhabitants',
#  595: 'leadership',
#  596: 'when',
#  597: 'had',
#  598: 'somethin',
#  599: 'nothing',
#  600: 'fantastically',
#  601: 'across',
#  602: 'times',
#  603: 'raising',
#  604: 'unrelenting',
#  605: 'principal',
#  606: 'pointed',
#  607: 'canoe',
#  608: 'hesitate',
#  609: 'unknown',
#  610: 'furniture',
#  611: 'earth',
#  612: 'affection',
#  613: 'rest',
#  614: 'substances',
#  615: 'intervals',
#  616: 'pausing',
#  617: 'kempelens',
#  618: 'studies',
#  619: 'greek',
#  620: 'generate',
#  621: 'thin',
#  622: 'remained',
#  623: 'desirous',
#  624: 'hand',
#  625: 'queer',
#  626: 'escaped',
#  627: 'disclosing',
#  628: 'contraction',
#  629: 'hectic',
#  630: 'has',
#  631: 'vain',
#  632: 'nigh',
#  633: 'gasped',
#  634: 'struggled',
#  635: 'self',
#  636: 'rich',
#  637: 'what',
#  638: 'analogy',
#  639: 'visits',
#  640: 'quivering',
#  641: 'island',
#  642: 'increase',
#  643: 'just',
#  644: 'connection',
#  645: 'phrase',
#  646: 'sunny',
#  647: 'able',
#  648: 'combat',
#  649: 'arter',
#  650: 'ruined',
#  651: 'firm',
#  652: 'size',
#  653: 'solemn',
#  654: 'speculation',
#  655: 'intrigues',
#  656: 'objects',
#  657: 'latin',
#  658: 'brow',
#  659: 'vestiges',
#  660: 'spread',
#  661: 'nature',
#  662: 'occasionally',
#  663: 'childrens',
#  664: 'snufy',
#  665: 'exultation',
#  666: 'meantime',
#  667: 'within',
#  668: 'spirit',
#  669: 'poison',
#  670: 'endure',
#  671: 'oh',
#  672: 'steps',
#  673: 'al',
#  674: 'almost',
#  675: 'shone',
#  676: 'after',
#  677: 'avoid',
#  678: 'means',
#  679: 'disapeared',
#  680: 'hope',
#  681: 'look',
#  682: 'nedles',
#  683: 'evidently',
#  684: 'imagination',
#  685: 'faded',
#  686: 'talked',
#  687: 'eastward',
#  688: 'want',
#  689: 'albertus',
#  690: 'respect',
#  691: 'where',
#  692: 'native',
#  693: 'ill',
#  694: 'impertinence',
#  695: 'o',
#  696: 'her',
#  697: 'never',
#  698: 'accustomed',
#  699: 'gave',
#  700: 'here',
#  701: 'thus',
#  702: 'accession',
#  703: 'casting',
#  704: 'grandfathers',
#  705: 'southern',
#  706: 'conclusion',
#  707: 'sparse',
#  708: 'proportions',
#  709: 'glare',
#  710: 'merival',
#  711: 'compases',
#  712: 'shrank',
#  713: 'wel',
#  714: 'even',
#  715: 'wonderful',
#  716: 'woe',
#  717: 'drift',
#  718: 'every',
#  719: 'climate',
#  720: 'understand',
#  721: 'immediate',
#  722: 'speeches',
#  723: 'trees',
#  724: 'torch',
#  725: 'an',
#  726: 'full',
#  727: 'ship',
#  728: 'minutely',
#  729: 'went',
#  730: 'unrecognised',
#  731: 'looking',
#  732: 'scant',
#  733: 'do',
#  734: 'intense',
#  735: 'deserted',
#  736: 'agripa',
#  737: 'beginin',
#  738: 'satisfaction',
#  739: 'collecting',
#  740: 'superintendent',
#  741: 'rendered',
#  742: 'panted',
#  743: 'organs',
#  744: 'country',
#  745: 'fro',
#  746: 'loved',
#  747: 'suggesting',
#  748: 'mewed',
#  749: 'infants',
#  750: 'building',
#  751: 'doubt',
#  752: 'underwent',
#  753: 'balconies',
#  754: 'pased',
#  755: 'men',
#  756: 'interment',
#  757: 'set',
#  758: 'abruptly',
#  759: 'prodigies',
#  760: 'disagreeable',
#  761: 'fire',
#  762: 'mud',
#  763: 'years',
#  764: 'very',
#  765: 'by',
#  766: 'shrines',
#  767: 'letters',
#  768: 'quasi',
#  769: 'raymond',
#  770: 'celebrated',
#  771: 'visibly',
#  772: 'traced',
#  773: 'age',
#  774: 'simply',
#  775: 'feminine',
#  776: 'secret',
#  777: 'season',
#  778: 'week',
#  779: 'two',
#  780: 'prophecies',
#  781: 'reverend',
#  782: 'behind',
#  783: 'thy',
#  784: 'than',
#  785: 'scrub',
#  786: 'stereotomy',
#  787: 'rain',
#  788: 'mobile',
#  789: 'maturity',
#  790: 'possessed',
#  791: 'fell',
#  792: 'but',
#  793: 'thou',
#  794: 'part',
#  795: 'windsor',
#  796: 'character',
#  797: 'him',
#  798: 'excep',
#  799: 'among',
#  800: 'refined',
#  801: 'bit',
#  802: 'again',
#  803: 'refuge',
#  804: 'discussed',
#  805: 'inopportuneness',
#  806: 'growth',
#  807: 'months',
#  808: 'ahead',
#  809: 'land',
#  810: 'attained',
#  811: 'judged',
#  812: 'observed',
#  813: 'doors',
#  814: 'room',
#  815: 'guesses',
#  816: 'wondrous',
#  817: 'confirmation',
#  818: 'lips',
#  819: 'many',
#  820: 'depth',
#  821: 'increased',
#  822: 'manner',
#  823: 'foaming',
#  824: 'epicurus',
#  825: 'constantly',
#  826: 'thoughtless',
#  827: 'aout',
#  828: 'countenance',
#  829: 'dilation',
#  830: 'bugs',
#  831: 'machine',
#  832: 'analysis',
#  833: 'serene',
#  834: 'pass',
#  835: 'glowing',
#  836: 'quartered',
#  837: 'act',
#  838: 'sunk',
#  839: 'date',
#  840: 'somewhat',
#  841: 'unsteady',
#  842: 'undue',
#  843: 'preternatural',
#  844: 'horizon',
#  845: 'speak',
#  846: 'could',
#  847: 'equal',
#  848: 'so',
#  849: 'violence',
#  850: 'delicate',
#  851: 'expenses',
#  852: 'paracelsus',
#  853: 'nets',
#  854: 'readily',
#  855: 'power',
#  856: 'regard',
#  857: 'cough',
#  858: 'myself',
#  859: 'eliciting',
#  860: 'been',
#  861: 'door',
#  862: 'should',
#  863: 'non',
#  864: 'struck',
#  865: 'grew',
#  866: 'languages',
#  867: 'cud',
#  868: 'passed',
#  869: 'symbol',
#  870: 'rock',
#  871: 'barls',
#  872: 'abaout',
#  873: 'expected',
#  874: 'unpleasant',
#  875: 'while',
#  876: 'laws',
#  877: 'availability',
#  878: 'engulfed',
#  879: 'placid',
#  880: 'heart',
#  881: 'pursy',
#  882: 'render',
#  883: 'pupils',
#  884: 'interpretation',
#  885: 'swiftly',
#  886: 'bite',
#  887: 'dare',
#  888: 'revealed',
#  889: 'adulthood',
#  890: 'twinge',
#  891: 'design',
#  892: 'importance',
#  893: 'aspect',
#  894: 'conceive',
#  895: 'disinclined',
#  896: 'desires',
#  897: 'chinlesnes',
#  898: 'society',
#  899: 'needed',
#  900: 'till',
#  901: 'equally',
#  902: 'lords',
#  903: 'herself',
#  904: 'frequent',
#  905: 'sarnath',
#  906: 'no',
#  907: 'next',
#  908: 'peculiarly',
#  909: 'money',
#  910: 'own',
#  911: 'itself',
#  912: 'ices',
#  913: 'think',
#  914: 'beings',
#  915: 'to',
#  916: 'such',
#  917: 'kindliness',
#  918: 'advancement',
#  919: 'madly',
#  920: 'guardian',
#  921: 'sense',
#  922: 'was',
#  923: 'horrible',
#  924: 'fet',
#  925: 'revived',
#  926: 'with',
#  927: 'extreme',
#  928: 'enabled',
#  929: 'is',
#  930: 'sacrifices',
#  931: 'watches',
#  932: 'shaped',
#  933: 'comprehension',
#  934: 'sordidness',
#  935: 'certain',
#  936: 'off',
#  937: 'were',
#  938: 'terific',
#  939: 'and',
#  940: 'steals',
#  941: 'held',
#  942: 'wrapping',
#  943: 'dark',
#  944: 'murmur',
#  945: 'yet',
#  946: 'cornelius',
#  947: 'fanciful',
#  948: 'developments',
#  949: 'can',
#  950: 'exclamations',
#  951: 'abroad',
#  952: 'habiliments',
#  953: 'heavy',
#  954: 'ample',
#  955: 'magnus',
#  956: 'this',
#  957: 'blankets',
#  958: 'around',
#  959: 'beyond',
#  960: 'sun',
#  961: 'ready',
#  962: 'cel',
#  963: 'sole',
#  964: 'disadvantages',
#  965: 'brought',
#  966: 'eye',
#  967: 'possible',
#  968: 'our',
#  969: 'brings',
#  970: 'for',
#  971: 'rigid',
#  972: 'caused',
#  973: 'follow',
#  974: 'conquest',
#  975: 'apparent',
#  976: 'mentioned',
#  977: 'glory',
#  978: 'usual',
#  979: 'idea',
#  980: 'as',
#  981: 'overthrow',
#  982: 'if',
#  983: 'of',
#  984: 'she',
#  985: 'afections',
#  986: 'young',
#  987: 'yourself',
#  988: 'robes',
#  989: 'carcas',
#  990: 'groundwork',
#  991: 'descended',
#  992: 'enterprise',
#  993: 'crew',
#  994: 'solitude',
#  995: 'brink',
#  996: 'scheme',
#  997: 'code',
#  998: 'surface',
#  999: 'distaste',
#  ...}

# %%
vocab_size = len(word2idx)
vocab_size
# Out:
# 1043

# %%
def generate_training_data(corpus, window_size):
    training_data = []
    for sentence in corpus:
        tokens = sentence.split()
        for i, target in enumerate(tokens):
            context_start = max(0, i - window_size)
            context_end = min(len(tokens), i + window_size + 1)
            for j in range(context_start, context_end):
                if i != j:
                    training_data.append((target, tokens[j]))
    return training_data

training_pairs = generate_training_data(x_train, WINDOW_SIZE)
training_pairs
# Out:
# [('with', 'how'),
#  ('with', 'deep'),
#  ('how', 'with'),
#  ('how', 'deep'),
#  ('how', 'a'),
#  ('deep', 'with'),
#  ('deep', 'how'),
#  ('deep', 'a'),
#  ('deep', 'spirit'),
#  ('a', 'how'),
#  ('a', 'deep'),
#  ('a', 'spirit'),
#  ('a', 'of'),
#  ('spirit', 'deep'),
#  ('spirit', 'a'),
#  ('spirit', 'of'),
#  ('spirit', 'wonder'),
#  ('of', 'a'),
#  ('of', 'spirit'),
#  ('of', 'wonder'),
#  ('of', 'and'),
#  ('wonder', 'spirit'),
#  ('wonder', 'of'),
#  ('wonder', 'and'),
#  ('wonder', 'perplexity'),
#  ('and', 'of'),
#  ('and', 'wonder'),
#  ('and', 'perplexity'),
#  ('and', 'was'),
#  ('perplexity', 'wonder'),
#  ('perplexity', 'and'),
#  ('perplexity', 'was'),
#  ('perplexity', 'i'),
#  ('was', 'and'),
#  ('was', 'perplexity'),
#  ('was', 'i'),
#  ('was', 'wont'),
#  ('i', 'perplexity'),
#  ('i', 'was'),
#  ('i', 'wont'),
#  ('i', 'to'),
#  ('wont', 'was'),
#  ('wont', 'i'),
#  ('wont', 'to'),
#  ('wont', 'regard'),
#  ('to', 'i'),
#  ('to', 'wont'),
#  ('to', 'regard'),
#  ('to', 'him'),
#  ('regard', 'wont'),
#  ('regard', 'to'),
#  ('regard', 'him'),
#  ('regard', 'from'),
#  ('him', 'to'),
#  ('him', 'regard'),
#  ('him', 'from'),
#  ('him', 'our'),
#  ('from', 'regard'),
#  ('from', 'him'),
#  ('from', 'our'),
#  ('from', 'remote'),
#  ('our', 'him'),
#  ('our', 'from'),
#  ('our', 'remote'),
#  ('our', 'pew'),
#  ('remote', 'from'),
#  ('remote', 'our'),
#  ('remote', 'pew'),
#  ('remote', 'in'),
#  ('pew', 'our'),
#  ('pew', 'remote'),
#  ('pew', 'in'),
#  ('pew', 'the'),
#  ('in', 'remote'),
#  ('in', 'pew'),
#  ('in', 'the'),
#  ('in', 'galery'),
#  ('the', 'pew'),
#  ('the', 'in'),
#  ('the', 'galery'),
#  ('the', 'as'),
#  ('galery', 'in'),
#  ('galery', 'the'),
#  ('galery', 'as'),
#  ('galery', 'with'),
#  ('as', 'the'),
#  ('as', 'galery'),
#  ('as', 'with'),
#  ('as', 'step'),
#  ('with', 'galery'),
#  ('with', 'as'),
#  ('with', 'step'),
#  ('with', 'solemn'),
#  ('step', 'as'),
#  ('step', 'with'),
#  ('step', 'solemn'),
#  ('step', 'and'),
#  ('solemn', 'with'),
#  ('solemn', 'step'),
#  ('solemn', 'and'),
#  ('solemn', 'slow'),
#  ('and', 'step'),
#  ('and', 'solemn'),
#  ('and', 'slow'),
#  ('and', 'he'),
#  ('slow', 'solemn'),
#  ('slow', 'and'),
#  ('slow', 'he'),
#  ('slow', 'ascended'),
#  ('he', 'and'),
#  ('he', 'slow'),
#  ('he', 'ascended'),
#  ('he', 'the'),
#  ('ascended', 'slow'),
#  ('ascended', 'he'),
#  ('ascended', 'the'),
#  ('ascended', 'pulpit'),
#  ('the', 'he'),
#  ('the', 'ascended'),
#  ('the', 'pulpit'),
#  ('the', 'this'),
#  ('pulpit', 'ascended'),
#  ('pulpit', 'the'),
#  ('pulpit', 'this'),
#  ('pulpit', 'reverend'),
#  ('this', 'the'),
#  ('this', 'pulpit'),
#  ('this', 'reverend'),
#  ('this', 'man'),
#  ('reverend', 'pulpit'),
#  ('reverend', 'this'),
#  ('reverend', 'man'),
#  ('reverend', 'with'),
#  ('man', 'this'),
#  ('man', 'reverend'),
#  ('man', 'with'),
#  ('man', 'countenance'),
#  ('with', 'reverend'),
#  ('with', 'man'),
#  ('with', 'countenance'),
#  ('with', 'so'),
#  ('countenance', 'man'),
#  ('countenance', 'with'),
#  ('countenance', 'so'),
#  ('countenance', 'demurely'),
#  ('so', 'with'),
#  ('so', 'countenance'),
#  ('so', 'demurely'),
#  ('so', 'benign'),
#  ('demurely', 'countenance'),
#  ('demurely', 'so'),
#  ('demurely', 'benign'),
#  ('demurely', 'with'),
#  ('benign', 'so'),
#  ('benign', 'demurely'),
#  ('benign', 'with'),
#  ('benign', 'robes'),
#  ('with', 'demurely'),
#  ('with', 'benign'),
#  ('with', 'robes'),
#  ('with', 'so'),
#  ('robes', 'benign'),
#  ('robes', 'with'),
#  ('robes', 'so'),
#  ('robes', 'glossy'),
#  ('so', 'with'),
#  ('so', 'robes'),
#  ('so', 'glossy'),
#  ('so', 'and'),
#  ('glossy', 'robes'),
#  ('glossy', 'so'),
#  ('glossy', 'and'),
#  ('glossy', 'so'),
#  ('and', 'so'),
#  ('and', 'glossy'),
#  ('and', 'so'),
#  ('and', 'clericaly'),
#  ('so', 'glossy'),
#  ('so', 'and'),
#  ('so', 'clericaly'),
#  ('so', 'flowing'),
#  ('clericaly', 'and'),
#  ('clericaly', 'so'),
#  ('clericaly', 'flowing'),
#  ('clericaly', 'with'),
#  ('flowing', 'so'),
#  ('flowing', 'clericaly'),
#  ('flowing', 'with'),
#  ('flowing', 'wig'),
#  ('with', 'clericaly'),
#  ('with', 'flowing'),
#  ('with', 'wig'),
#  ('with', 'so'),
#  ('wig', 'flowing'),
#  ('wig', 'with'),
#  ('wig', 'so'),
#  ('wig', 'minutely'),
#  ('so', 'with'),
#  ('so', 'wig'),
#  ('so', 'minutely'),
#  ('so', 'powdered'),
#  ('minutely', 'wig'),
#  ('minutely', 'so'),
#  ('minutely', 'powdered'),
#  ('minutely', 'so'),
#  ('powdered', 'so'),
#  ('powdered', 'minutely'),
#  ('powdered', 'so'),
#  ('powdered', 'rigid'),
#  ('so', 'minutely'),
#  ('so', 'powdered'),
#  ('so', 'rigid'),
#  ('so', 'and'),
#  ('rigid', 'powdered'),
#  ('rigid', 'so'),
#  ('rigid', 'and'),
#  ('rigid', 'so'),
#  ('and', 'so'),
#  ('and', 'rigid'),
#  ('and', 'so'),
#  ('and', 'vast'),
#  ('so', 'rigid'),
#  ('so', 'and'),
#  ('so', 'vast'),
#  ('so', 'could'),
#  ('vast', 'and'),
#  ('vast', 'so'),
#  ('vast', 'could'),
#  ('vast', 'this'),
#  ('could', 'so'),
#  ('could', 'vast'),
#  ('could', 'this'),
#  ('could', 'be'),
#  ('this', 'vast'),
#  ('this', 'could'),
#  ('this', 'be'),
#  ('this', 'he'),
#  ('be', 'could'),
#  ('be', 'this'),
#  ('be', 'he'),
#  ('be', 'who'),
#  ('he', 'this'),
#  ('he', 'be'),
#  ('he', 'who'),
#  ('he', 'of'),
#  ('who', 'be'),
#  ('who', 'he'),
#  ('who', 'of'),
#  ('who', 'late'),
#  ('of', 'he'),
#  ('of', 'who'),
#  ('of', 'late'),
#  ('of', 'with'),
#  ('late', 'who'),
#  ('late', 'of'),
#  ('late', 'with'),
#  ('late', 'sour'),
#  ('with', 'of'),
#  ('with', 'late'),
#  ('with', 'sour'),
#  ('with', 'visage'),
#  ('sour', 'late'),
#  ('sour', 'with'),
#  ('sour', 'visage'),
#  ('sour', 'and'),
#  ('visage', 'with'),
#  ('visage', 'sour'),
#  ('visage', 'and'),
#  ('visage', 'in'),
#  ('and', 'sour'),
#  ('and', 'visage'),
#  ('and', 'in'),
#  ('and', 'snufy'),
#  ('in', 'visage'),
#  ('in', 'and'),
#  ('in', 'snufy'),
#  ('in', 'habiliments'),
#  ('snufy', 'and'),
#  ('snufy', 'in'),
#  ('snufy', 'habiliments'),
#  ('snufy', 'administered'),
#  ('habiliments', 'in'),
#  ('habiliments', 'snufy'),
#  ('habiliments', 'administered'),
#  ('habiliments', 'ferule'),
#  ('administered', 'snufy'),
#  ('administered', 'habiliments'),
#  ('administered', 'ferule'),
#  ('administered', 'in'),
#  ('ferule', 'habiliments'),
#  ('ferule', 'administered'),
#  ('ferule', 'in'),
#  ('ferule', 'hand'),
#  ('in', 'administered'),
#  ('in', 'ferule'),
#  ('in', 'hand'),
#  ('in', 'the'),
#  ('hand', 'ferule'),
#  ('hand', 'in'),
#  ('hand', 'the'),
#  ('hand', 'draconian'),
#  ('the', 'in'),
#  ('the', 'hand'),
#  ('the', 'draconian'),
#  ('the', 'laws'),
#  ('draconian', 'hand'),
#  ('draconian', 'the'),
#  ('draconian', 'laws'),
#  ('draconian', 'of'),
#  ('laws', 'the'),
#  ('laws', 'draconian'),
#  ('laws', 'of'),
#  ('laws', 'the'),
#  ('of', 'draconian'),
#  ('of', 'laws'),
#  ('of', 'the'),
#  ('of', 'academy'),
#  ('the', 'laws'),
#  ('the', 'of'),
#  ('the', 'academy'),
#  ('academy', 'of'),
#  ('academy', 'the'),
#  ('our', 'compases'),
#  ('our', 'depth'),
#  ('compases', 'our'),
#  ('compases', 'depth'),
#  ('compases', 'gauges'),
#  ('depth', 'our'),
#  ('depth', 'compases'),
#  ('depth', 'gauges'),
#  ('depth', 'and'),
#  ('gauges', 'compases'),
#  ('gauges', 'depth'),
#  ('gauges', 'and'),
#  ('gauges', 'other'),
#  ('and', 'depth'),
#  ('and', 'gauges'),
#  ('and', 'other'),
#  ('and', 'delicate'),
#  ('other', 'gauges'),
#  ('other', 'and'),
#  ('other', 'delicate'),
#  ('other', 'instruments'),
#  ('delicate', 'and'),
#  ('delicate', 'other'),
#  ('delicate', 'instruments'),
#  ('delicate', 'were'),
#  ('instruments', 'other'),
#  ('instruments', 'delicate'),
#  ('instruments', 'were'),
#  ('instruments', 'ruined'),
#  ('were', 'delicate'),
#  ('were', 'instruments'),
#  ('were', 'ruined'),
#  ('were', 'so'),
#  ('ruined', 'instruments'),
#  ('ruined', 'were'),
#  ('ruined', 'so'),
#  ('ruined', 'that'),
#  ('so', 'were'),
#  ('so', 'ruined'),
#  ('so', 'that'),
#  ('so', 'henceforth'),
#  ('that', 'ruined'),
#  ('that', 'so'),
#  ('that', 'henceforth'),
#  ('that', 'our'),
#  ('henceforth', 'so'),
#  ('henceforth', 'that'),
#  ('henceforth', 'our'),
#  ('henceforth', 'only'),
#  ('our', 'that'),
#  ('our', 'henceforth'),
#  ('our', 'only'),
#  ('our', 'reckoning'),
#  ('only', 'henceforth'),
#  ('only', 'our'),
#  ('only', 'reckoning'),
#  ('only', 'would'),
#  ('reckoning', 'our'),
#  ('reckoning', 'only'),
#  ('reckoning', 'would'),
#  ('reckoning', 'be'),
#  ('would', 'only'),
#  ('would', 'reckoning'),
#  ('would', 'be'),
#  ('would', 'gueswork'),
#  ('be', 'reckoning'),
#  ('be', 'would'),
#  ('be', 'gueswork'),
#  ('be', 'based'),
#  ('gueswork', 'would'),
#  ('gueswork', 'be'),
#  ('gueswork', 'based'),
#  ('gueswork', 'on'),
#  ('based', 'be'),
#  ('based', 'gueswork'),
#  ('based', 'on'),
#  ('based', 'our'),
#  ('on', 'gueswork'),
#  ('on', 'based'),
#  ('on', 'our'),
#  ('on', 'watches'),
#  ('our', 'based'),
#  ('our', 'on'),
#  ('our', 'watches'),
#  ('our', 'the'),
#  ('watches', 'on'),
#  ('watches', 'our'),
#  ('watches', 'the'),
#  ('watches', 'calendar'),
#  ('the', 'our'),
#  ('the', 'watches'),
#  ('the', 'calendar'),
#  ('the', 'and'),
#  ('calendar', 'watches'),
#  ('calendar', 'the'),
#  ('calendar', 'and'),
#  ('calendar', 'our'),
#  ('and', 'the'),
#  ('and', 'calendar'),
#  ('and', 'our'),
#  ('and', 'apparent'),
#  ('our', 'calendar'),
#  ('our', 'and'),
#  ('our', 'apparent'),
#  ('our', 'drift'),
#  ('apparent', 'and'),
#  ('apparent', 'our'),
#  ('apparent', 'drift'),
#  ('apparent', 'as'),
#  ('drift', 'our'),
#  ('drift', 'apparent'),
#  ('drift', 'as'),
#  ('drift', 'judged'),
#  ('as', 'apparent'),
#  ('as', 'drift'),
#  ('as', 'judged'),
#  ('as', 'by'),
#  ('judged', 'drift'),
#  ('judged', 'as'),
#  ('judged', 'by'),
#  ('judged', 'any'),
#  ('by', 'as'),
#  ('by', 'judged'),
#  ('by', 'any'),
#  ('by', 'objects'),
#  ('any', 'judged'),
#  ('any', 'by'),
#  ('any', 'objects'),
#  ('any', 'we'),
#  ('objects', 'by'),
#  ('objects', 'any'),
#  ('objects', 'we'),
#  ('objects', 'might'),
#  ('we', 'any'),
#  ('we', 'objects'),
#  ('we', 'might'),
#  ('we', 'spy'),
#  ('might', 'objects'),
#  ('might', 'we'),
#  ('might', 'spy'),
#  ('might', 'through'),
#  ('spy', 'we'),
#  ('spy', 'might'),
#  ('spy', 'through'),
#  ('spy', 'the'),
#  ('through', 'might'),
#  ('through', 'spy'),
#  ('through', 'the'),
#  ('through', 'portholes'),
#  ('the', 'spy'),
#  ('the', 'through'),
#  ('the', 'portholes'),
#  ('the', 'or'),
#  ('portholes', 'through'),
#  ('portholes', 'the'),
#  ('portholes', 'or'),
#  ('portholes', 'from'),
#  ('or', 'the'),
#  ('or', 'portholes'),
#  ('or', 'from'),
#  ('or', 'the'),
#  ('from', 'portholes'),
#  ('from', 'or'),
#  ('from', 'the'),
#  ('from', 'conning'),
#  ('the', 'or'),
#  ('the', 'from'),
#  ('the', 'conning'),
#  ('the', 'tower'),
#  ('conning', 'from'),
#  ('conning', 'the'),
#  ('conning', 'tower'),
#  ('tower', 'the'),
#  ('tower', 'conning'),
#  ('ahead', 'lay'),
#  ('ahead', 'sparse'),
#  ('lay', 'ahead'),
#  ('lay', 'sparse'),
#  ('lay', 'grass'),
#  ('sparse', 'ahead'),
#  ('sparse', 'lay'),
#  ('sparse', 'grass'),
#  ('sparse', 'and'),
#  ('grass', 'lay'),
#  ('grass', 'sparse'),
#  ('grass', 'and'),
#  ('grass', 'scrub'),
#  ('and', 'sparse'),
#  ('and', 'grass'),
#  ('and', 'scrub'),
#  ('and', 'blueberry'),
#  ('scrub', 'grass'),
#  ('scrub', 'and'),
#  ('scrub', 'blueberry'),
#  ('scrub', 'bushes'),
#  ('blueberry', 'and'),
#  ('blueberry', 'scrub'),
#  ('blueberry', 'bushes'),
#  ('blueberry', 'and'),
#  ('bushes', 'scrub'),
#  ('bushes', 'blueberry'),
#  ('bushes', 'and'),
#  ('bushes', 'beyond'),
#  ('and', 'blueberry'),
#  ('and', 'bushes'),
#  ('and', 'beyond'),
#  ('and', 'them'),
#  ('beyond', 'bushes'),
#  ('beyond', 'and'),
#  ('beyond', 'them'),
#  ('beyond', 'the'),
#  ('them', 'and'),
#  ('them', 'beyond'),
#  ('them', 'the'),
#  ('them', 'naked'),
#  ('the', 'beyond'),
#  ('the', 'them'),
#  ('the', 'naked'),
#  ('the', 'rock'),
#  ('naked', 'them'),
#  ('naked', 'the'),
#  ('naked', 'rock'),
#  ('naked', 'of'),
#  ('rock', 'the'),
#  ('rock', 'naked'),
#  ('rock', 'of'),
#  ('rock', 'the'),
#  ('of', 'naked'),
#  ('of', 'rock'),
#  ('of', 'the'),
#  ('of', 'crag'),
#  ('the', 'rock'),
#  ('the', 'of'),
#  ('the', 'crag'),
#  ('the', 'and'),
#  ('crag', 'of'),
#  ('crag', 'the'),
#  ('crag', 'and'),
#  ('crag', 'the'),
#  ('and', 'the'),
#  ('and', 'crag'),
#  ('and', 'the'),
#  ('and', 'thin'),
#  ('the', 'crag'),
#  ('the', 'and'),
#  ('the', 'thin'),
#  ('the', 'peak'),
#  ('thin', 'and'),
#  ('thin', 'the'),
#  ('thin', 'peak'),
#  ('thin', 'of'),
#  ('peak', 'the'),
#  ('peak', 'thin'),
#  ('peak', 'of'),
#  ('peak', 'the'),
#  ('of', 'thin'),
#  ('of', 'peak'),
#  ('of', 'the'),
#  ('of', 'dreaded'),
#  ('the', 'peak'),
#  ('the', 'of'),
#  ('the', 'dreaded'),
#  ('the', 'grey'),
#  ('dreaded', 'of'),
#  ('dreaded', 'the'),
#  ('dreaded', 'grey'),
#  ('dreaded', 'cotage'),
#  ('grey', 'the'),
#  ('grey', 'dreaded'),
#  ('grey', 'cotage'),
#  ('cotage', 'dreaded'),
#  ('cotage', 'grey'),
#  ('dr', 'johnson'),
#  ('dr', 'as'),
#  ('johnson', 'dr'),
#  ('johnson', 'as'),
#  ('johnson', 'i'),
#  ('as', 'dr'),
#  ('as', 'johnson'),
#  ('as', 'i'),
#  ('as', 'beheld'),
#  ('i', 'johnson'),
#  ('i', 'as'),
#  ('i', 'beheld'),
#  ('i', 'him'),
#  ('beheld', 'as'),
#  ('beheld', 'i'),
#  ('beheld', 'him'),
#  ('beheld', 'was'),
#  ('him', 'i'),
#  ('him', 'beheld'),
#  ('him', 'was'),
#  ('him', 'a'),
#  ('was', 'beheld'),
#  ('was', 'him'),
#  ('was', 'a'),
#  ('was', 'ful'),
#  ('a', 'him'),
#  ('a', 'was'),
#  ('a', 'ful'),
#  ('a', 'pursy'),
#  ('ful', 'was'),
#  ('ful', 'a'),
#  ('ful', 'pursy'),
#  ('ful', 'man'),
#  ('pursy', 'a'),
#  ('pursy', 'ful'),
#  ('pursy', 'man'),
#  ('pursy', 'very'),
#  ('man', 'ful'),
#  ('man', 'pursy'),
#  ('man', 'very'),
#  ('man', 'ill'),
#  ('very', 'pursy'),
#  ('very', 'man'),
#  ('very', 'ill'),
#  ('very', 'drest'),
#  ('ill', 'man'),
#  ('ill', 'very'),
#  ('ill', 'drest'),
#  ('ill', 'and'),
#  ('drest', 'very'),
#  ('drest', 'ill'),
#  ('drest', 'and'),
#  ('drest', 'of'),
#  ('and', 'ill'),
#  ('and', 'drest'),
#  ('and', 'of'),
#  ('and', 'slovenly'),
#  ('of', 'drest'),
#  ('of', 'and'),
#  ('of', 'slovenly'),
#  ('of', 'aspect'),
#  ('slovenly', 'and'),
#  ('slovenly', 'of'),
#  ('slovenly', 'aspect'),
#  ('aspect', 'of'),
#  ('aspect', 'slovenly'),
#  ('the', 'next'),
#  ('the', 'morning'),
#  ('next', 'the'),
#  ('next', 'morning'),
#  ('next', 'i'),
#  ('morning', 'the'),
#  ('morning', 'next'),
#  ('morning', 'i'),
#  ('morning', 'delivered'),
#  ('i', 'next'),
#  ('i', 'morning'),
#  ('i', 'delivered'),
#  ('i', 'my'),
#  ('delivered', 'morning'),
#  ('delivered', 'i'),
#  ('delivered', 'my'),
#  ('delivered', 'letters'),
#  ('my', 'i'),
#  ('my', 'delivered'),
#  ('my', 'letters'),
#  ('my', 'of'),
#  ('letters', 'delivered'),
#  ('letters', 'my'),
#  ('letters', 'of'),
#  ('letters', 'introduction'),
#  ('of', 'my'),
#  ('of', 'letters'),
#  ('of', 'introduction'),
#  ('of', 'and'),
#  ('introduction', 'letters'),
#  ('introduction', 'of'),
#  ('introduction', 'and'),
#  ('introduction', 'paid'),
#  ('and', 'of'),
#  ('and', 'introduction'),
#  ('and', 'paid'),
#  ('and', 'a'),
#  ('paid', 'introduction'),
#  ('paid', 'and'),
#  ('paid', 'a'),
#  ('paid', 'visit'),
#  ('a', 'and'),
#  ('a', 'paid'),
#  ('a', 'visit'),
#  ('a', 'to'),
#  ('visit', 'paid'),
#  ('visit', 'a'),
#  ('visit', 'to'),
#  ('visit', 'some'),
#  ('to', 'a'),
#  ('to', 'visit'),
#  ('to', 'some'),
#  ('to', 'of'),
#  ('some', 'visit'),
#  ('some', 'to'),
#  ('some', 'of'),
#  ('some', 'the'),
#  ('of', 'to'),
#  ('of', 'some'),
#  ('of', 'the'),
#  ('of', 'principal'),
#  ('the', 'some'),
#  ('the', 'of'),
#  ('the', 'principal'),
#  ('the', 'profesors'),
#  ('principal', 'of'),
#  ('principal', 'the'),
#  ('principal', 'profesors'),
#  ('profesors', 'the'),
#  ('profesors', 'principal'),
#  ('i', 'seemed'),
#  ('i', 'to'),
#  ('seemed', 'i'),
#  ('seemed', 'to'),
#  ('seemed', 'be'),
#  ('to', 'i'),
#  ('to', 'seemed'),
#  ('to', 'be'),
#  ('to', 'upon'),
#  ('be', 'seemed'),
#  ('be', 'to'),
#  ('be', 'upon'),
#  ('be', 'the'),
#  ('upon', 'to'),
#  ('upon', 'be'),
#  ('upon', 'the'),
#  ('upon', 'verge'),
#  ('the', 'be'),
#  ('the', 'upon'),
#  ('the', 'verge'),
#  ('the', 'of'),
#  ('verge', 'upon'),
#  ('verge', 'the'),
#  ('verge', 'of'),
#  ('verge', 'comprehension'),
#  ('of', 'the'),
#  ('of', 'verge'),
#  ('of', 'comprehension'),
#  ('of', 'without'),
#  ('comprehension', 'verge'),
#  ('comprehension', 'of'),
#  ('comprehension', 'without'),
#  ('comprehension', 'power'),
#  ('without', 'of'),
#  ('without', 'comprehension'),
#  ('without', 'power'),
#  ('without', 'to'),
#  ('power', 'comprehension'),
#  ('power', 'without'),
#  ('power', 'to'),
#  ('power', 'comprehend'),
#  ('to', 'without'),
#  ('to', 'power'),
#  ('to', 'comprehend'),
#  ('to', 'men'),
#  ('comprehend', 'power'),
#  ('comprehend', 'to'),
#  ('comprehend', 'men'),
#  ('comprehend', 'at'),
#  ('men', 'to'),
#  ('men', 'comprehend'),
#  ('men', 'at'),
#  ('men', 'times'),
#  ('at', 'comprehend'),
#  ('at', 'men'),
#  ('at', 'times'),
#  ('at', 'find'),
#  ('times', 'men'),
#  ('times', 'at'),
#  ('times', 'find'),
#  ('times', 'themselves'),
#  ('find', 'at'),
#  ('find', 'times'),
#  ('find', 'themselves'),
#  ('find', 'upon'),
#  ('themselves', 'times'),
#  ('themselves', 'find'),
#  ('themselves', 'upon'),
#  ('themselves', 'the'),
#  ('upon', 'find'),
#  ('upon', 'themselves'),
#  ('upon', 'the'),
#  ('upon', 'brink'),
#  ('the', 'themselves'),
#  ('the', 'upon'),
#  ('the', 'brink'),
#  ('the', 'of'),
#  ('brink', 'upon'),
#  ('brink', 'the'),
#  ('brink', 'of'),
#  ('brink', 'remembrance'),
#  ('of', 'the'),
#  ('of', 'brink'),
#  ('of', 'remembrance'),
#  ('of', 'without'),
#  ('remembrance', 'brink'),
#  ('remembrance', 'of'),
#  ('remembrance', 'without'),
#  ('remembrance', 'being'),
#  ('without', 'of'),
#  ('without', 'remembrance'),
#  ('without', 'being'),
#  ('without', 'able'),
#  ('being', 'remembrance'),
#  ('being', 'without'),
#  ('being', 'able'),
#  ('being', 'in'),
#  ('able', 'without'),
#  ('able', 'being'),
#  ('able', 'in'),
#  ('able', 'the'),
#  ('in', 'being'),
#  ('in', 'able'),
#  ('in', 'the'),
#  ('in', 'end'),
#  ('the', 'able'),
#  ('the', 'in'),
#  ('the', 'end'),
#  ('the', 'to'),
#  ('end', 'in'),
#  ('end', 'the'),
#  ('end', 'to'),
#  ('end', 'remember'),
#  ('to', 'the'),
#  ('to', 'end'),
#  ('to', 'remember'),
#  ('remember', 'end'),
#  ('remember', 'to'),
#  ('i', 'pointed'),
#  ('i', 'to'),
#  ('pointed', 'i'),
#  ('pointed', 'to'),
#  ('pointed', 'the'),
#  ('to', 'i'),
#  ('to', 'pointed'),
#  ('to', 'the'),
#  ('to', 'spot'),
#  ('the', 'pointed'),
#  ('the', 'to'),
#  ('the', 'spot'),
#  ('the', 'where'),
#  ('spot', 'to'),
#  ('spot', 'the'),
#  ('spot', 'where'),
#  ('spot', 'he'),
#  ('where', 'the'),
#  ('where', 'spot'),
#  ('where', 'he'),
#  ('where', 'had'),
#  ('he', 'spot'),
#  ('he', 'where'),
#  ('he', 'had'),
#  ('he', 'disapeared'),
#  ('had', 'where'),
#  ('had', 'he'),
#  ('had', 'disapeared'),
#  ('had', 'and'),
#  ('disapeared', 'he'),
#  ('disapeared', 'had'),
#  ('disapeared', 'and'),
#  ('disapeared', 'we'),
#  ('and', 'had'),
#  ('and', 'disapeared'),
#  ('and', 'we'),
#  ('and', 'followed'),
#  ('we', 'disapeared'),
#  ('we', 'and'),
#  ('we', 'followed'),
#  ('we', 'the'),
#  ('followed', 'and'),
#  ('followed', 'we'),
#  ('followed', 'the'),
#  ('followed', 'track'),
#  ('the', 'we'),
#  ('the', 'followed'),
#  ('the', 'track'),
#  ('the', 'with'),
#  ('track', 'followed'),
#  ('track', 'the'),
#  ('track', 'with'),
#  ('track', 'boats'),
#  ('with', 'the'),
#  ('with', 'track'),
#  ('with', 'boats'),
#  ('with', 'nets'),
#  ('boats', 'track'),
#  ('boats', 'with'),
#  ('boats', 'nets'),
#  ('boats', 'were'),
#  ('nets', 'with'),
#  ('nets', 'boats'),
#  ('nets', 'were'),
#  ('nets', 'cast'),
#  ('were', 'boats'),
#  ('were', 'nets'),
#  ('were', 'cast'),
#  ('were', 'but'),
#  ('cast', 'nets'),
#  ('cast', 'were'),
#  ('cast', 'but'),
#  ('cast', 'in'),
#  ('but', 'were'),
#  ('but', 'cast'),
#  ('but', 'in'),
#  ('but', 'vain'),
#  ('in', 'cast'),
#  ('in', 'but'),
#  ('in', 'vain'),
#  ('vain', 'but'),
#  ('vain', 'in'),
#  ('finding', 'nothing'),
#  ('finding', 'else'),
#  ('nothing', 'finding'),
#  ('nothing', 'else'),
#  ('nothing', 'not'),
#  ('else', 'finding'),
#  ('else', 'nothing'),
#  ('else', 'not'),
#  ('else', 'even'),
#  ('not', 'nothing'),
#  ('not', 'else'),
#  ('not', 'even'),
#  ('not', 'gold'),
#  ('even', 'else'),
#  ('even', 'not'),
#  ('even', 'gold'),
#  ('even', 'the'),
#  ('gold', 'not'),
#  ('gold', 'even'),
#  ('gold', 'the'),
#  ('gold', 'superintendent'),
#  ('the', 'even'),
#  ('the', 'gold'),
#  ('the', 'superintendent'),
#  ('the', 'abandoned'),
#  ('superintendent', 'gold'),
#  ('superintendent', 'the'),
#  ('superintendent', 'abandoned'),
#  ('superintendent', 'his'),
#  ('abandoned', 'the'),
#  ('abandoned', 'superintendent'),
#  ('abandoned', 'his'),
#  ('abandoned', 'atempts'),
#  ('his', 'superintendent'),
#  ('his', 'abandoned'),
#  ('his', 'atempts'),
#  ('his', 'but'),
#  ('atempts', 'abandoned'),
#  ('atempts', 'his'),
#  ('atempts', 'but'),
#  ('atempts', 'a'),
#  ('but', 'his'),
#  ('but', 'atempts'),
#  ('but', 'a'),
#  ('but', 'perplexed'),
#  ('a', 'atempts'),
#  ('a', 'but'),
#  ('a', 'perplexed'),
#  ('a', 'look'),
#  ('perplexed', 'but'),
#  ('perplexed', 'a'),
#  ('perplexed', 'look'),
#  ('perplexed', 'occasionally'),
#  ('look', 'a'),
#  ('look', 'perplexed'),
#  ('look', 'occasionally'),
#  ('look', 'steals'),
#  ('occasionally', 'perplexed'),
#  ('occasionally', 'look'),
#  ('occasionally', 'steals'),
#  ('occasionally', 'over'),
#  ('steals', 'look'),
#  ('steals', 'occasionally'),
#  ('steals', 'over'),
#  ('steals', 'his'),
#  ('over', 'occasionally'),
#  ('over', 'steals'),
#  ('over', 'his'),
#  ('over', 'countenance'),
#  ('his', 'steals'),
#  ...]

# %%
def one_hot_encode(word, vocab_size):
    vec = np.zeros(vocab_size)
    vec[word2idx[word]] = 1
    return vec

# %%
w1 = np.random.randn(vocab_size, EMBEDDING_DIM) 
w2 = np.random.randn(EMBEDDING_DIM, vocab_size) 

w1, w2
# Out:
# (array([[ 0.57808348, -0.44941274, -0.59547342, -0.20834122,  0.43269667],
#         [ 0.0731849 ,  0.74941475,  0.31552233, -0.11652877,  2.91690762],
#         [ 1.15535482, -0.25508097,  0.59011547,  0.94506131, -0.25941199],
#         ...,
#         [-0.46458744,  0.61611883,  1.10354216, -0.45376386,  1.49453995],
#         [ 0.52960461,  1.25314752,  0.44206835,  1.14947591,  0.7322041 ],
#         [-2.01788606,  0.75038341, -0.80644126, -0.47293836, -0.06147192]]),
#  array([[-0.31828883,  1.46334329, -0.40074627, ..., -0.59590921,
#          -0.04209981,  0.07130813],
#         [-0.28119764, -1.49093918, -0.57386887, ..., -1.81554218,
#          -0.0175976 , -2.65323574],
#         [-0.47656384, -0.19985388,  1.31032252, ...,  0.60935749,
#          -1.14373644,  0.14179412],
#         [-0.33546129, -0.8382469 ,  0.10759369, ..., -0.66683825,
#           1.02116027, -0.63798518],
#         [ 1.63685262,  0.5169095 ,  0.61919581, ..., -0.27081419,
#           0.26120988, -1.39715806]]))

# %%
for epoch in range(EPOCHS):
    total_loss = 0
    for target_word, context_word in training_pairs:

        # forward
        target_vec = one_hot_encode(target_word, vocab_size)
        hidden_layer = np.dot(w1.T, target_vec) 
        output_layer = np.dot(w2.T, hidden_layer) 
        # softmax
        predictions = np.exp(output_layer) / np.sum(np.exp(output_layer)) 

        # loss
        target_label = one_hot_encode(context_word, vocab_size)
        loss = -np.sum(target_label * np.log(predictions + 1e-9))
        total_loss += loss

        # backward
        error = predictions - target_label
        w2 -= LEARNING_RATE * np.outer(hidden_layer, error)
        w1 -= LEARNING_RATE * np.outer(target_vec, np.dot(w2, error))
    
    print(f"epoch {epoch}, loss: {loss:.4f}, total loss: {total_loss:.4f}")
# Out:
# epoch 0, loss: 7.1959, total loss: 75490.4016
# epoch 1, loss: 6.6823, total loss: 70284.4320
# epoch 2, loss: 6.0274, total loss: 68071.3250
# epoch 3, loss: 5.2186, total loss: 66463.3203
# epoch 4, loss: 4.2679, total loss: 65088.9365
# epoch 5, loss: 3.2715, total loss: 63807.7872
# epoch 6, loss: 2.4597, total loss: 62578.2193
# epoch 7, loss: 1.9973, total loss: 61418.1136
# epoch 8, loss: 1.8015, total loss: 60345.3803
# epoch 9, loss: 1.7337, total loss: 59359.4786
# epoch 10, loss: 1.7130, total loss: 58456.3707
# epoch 11, loss: 1.7071, total loss: 57631.0681
# epoch 12, loss: 1.7077, total loss: 56876.1846
# epoch 13, loss: 1.7133, total loss: 56185.2149
# epoch 14, loss: 1.7229, total loss: 55553.8284
# epoch 15, loss: 1.7357, total loss: 54978.3114
# epoch 16, loss: 1.7513, total loss: 54454.5977
# epoch 17, loss: 1.7694, total loss: 53978.3258
# epoch 18, loss: 1.7897, total loss: 53545.2147
# epoch 19, loss: 1.8116, total loss: 53151.3055
# epoch 20, loss: 1.8346, total loss: 52792.9669
# epoch 21, loss: 1.8582, total loss: 52466.7770
# epoch 22, loss: 1.8819, total loss: 52169.4346
# epoch 23, loss: 1.9054, total loss: 51897.7520
# epoch 24, loss: 1.9281, total loss: 51648.6982
# epoch 25, loss: 1.9500, total loss: 51419.4645
# epoch 26, loss: 1.9707, total loss: 51207.5239
# epoch 27, loss: 1.9902, total loss: 51010.6585
# epoch 28, loss: 2.0085, total loss: 50826.9545
# epoch 29, loss: 2.0256, total loss: 50654.7792
# epoch 30, loss: 2.0417, total loss: 50492.7498
# epoch 31, loss: 2.0569, total loss: 50339.6949
# epoch 32, loss: 2.0714, total loss: 50194.6156
# epoch 33, loss: 2.0852, total loss: 50056.6504
# epoch 34, loss: 2.0985, total loss: 49925.0469
# epoch 35, loss: 2.1114, total loss: 49799.1436
# epoch 36, loss: 2.1240, total loss: 49678.3581
# epoch 37, loss: 2.1364, total loss: 49562.1788
# epoch 38, loss: 2.1486, total loss: 49450.1555
# epoch 39, loss: 2.1607, total loss: 49341.8899
# epoch 40, loss: 2.1727, total loss: 49237.0275
# epoch 41, loss: 2.1847, total loss: 49135.2523
# epoch 42, loss: 2.1966, total loss: 49036.2833
# epoch 43, loss: 2.2086, total loss: 48939.8729
# epoch 44, loss: 2.2205, total loss: 48845.8044
# epoch 45, loss: 2.2325, total loss: 48753.8895
# epoch 46, loss: 2.2444, total loss: 48663.9652
# epoch 47, loss: 2.2564, total loss: 48575.8905
# epoch 48, loss: 2.2683, total loss: 48489.5436
# epoch 49, loss: 2.2802, total loss: 48404.8188

# %%
def get_sentence_embedding(sentence, w1, word2idx):
    words = sentence.split()
    vectors = [w1[word2idx[word]] for word in words if word in word2idx]
    if len(vectors) == 0:
        return np.zeros(w1.shape[1]) 
    return np.mean(vectors, axis=0) 

x_train_skip_gram = np.array([get_sentence_embedding(sentence, w1, word2idx) for sentence in x_train])
x_test_skip_gram = np.array([get_sentence_embedding(sentence, w1, word2idx) for sentence in x_test])

# %% [markdown]
# ## H. entrainement/test

# %% [markdown]
# result

# %%
def train_and_evaluate(X_train, X_test, y_train, y_test):
    mlp = MLPClassifier(hidden_layer_sizes=(20,), max_iter=20, random_state=0)
    mlp.fit(X_train, y_train)
    
    y_train_pred = mlp.predict(X_train)
    y_test_pred = mlp.predict(X_test)
    
    print("train classification report:")
    print(classification_report(y_train, y_train_pred))
    print("test classification report:")
    print(classification_report(y_test, y_test_pred))
    
    start_time = time.time()
    mlp.predict(X_test)
    print(f"prediction time: {time.time() - start_time:.5f} seconds")

# %%
print("skip-gram results:")
train_and_evaluate(x_train_skip_gram, x_test_skip_gram, y_train, y_test)
# Out:
# skip-gram results:
# train classification report:
#               precision    recall  f1-score   support
#
#            0       0.38      0.29      0.33        28
#            1       0.25      0.20      0.22        20
#            2       0.21      0.32      0.25        22
#
#     accuracy                           0.27        70
#    macro avg       0.28      0.27      0.27        70
# weighted avg       0.29      0.27      0.27        70
#
# test classification report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.33      0.42        12
#            1       0.30      0.33      0.32         9
#            2       0.38      0.56      0.45         9
#
#     accuracy                           0.40        30
#    macro avg       0.42      0.41      0.40        30
# weighted avg       0.43      0.40      0.40        30
#
# prediction time: 0.00046 seconds
# /home/mina/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (20) reached and the optimization hasn't converged yet.
#   warnings.warn(
